# %% [markdown]
# # Random Forest Model

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import helper_functions as hf
import RandomPrediction as rp
import dataframe_image as dfi
from itertools import product

# %%
df = hf.load_data()
df = hf.create_engineered_plus_fundamental_features(df)
df = hf.create_binary_labels(df,[1,20,60])

raw = ['ret','volume']
eng = [
    'mean_20', 'mean_60',
    'vol_20', 'vol_60',
    'mom_20', 'mom_60',
    'ema_12', 'ema_26', 'ema_cross',
    'skew_20', 'skew_60',
    'kurt_20', 'kurt_60',
    'vol_z'
]
fund = [
    'eps',
    'profit_margin',
    'revenue_growth',
    'income_growth',
    'gross_margin',
    'operating_margin',
    'sga_ratio',
    'rd_ratio',
    'cost_ratio',
    'net_income_per_share',
    'tax_burden',
    'nonop_ratio',
    'abnormal_ratio',
    'revenue_per_share',
    'da_ratio',
    'interest_coverage',
    'interest_burden'
]
fund_eng = fund + eng 

#rt = df.pivot(index='date', columns='ticker', values='ret')
# Out:
# /Users/evi/Desktop/ML-Stock-Predictor/helper_functions.py:64: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['revenue_growth'] = df.groupby('ticker')['revenue'].pct_change()
# /Users/evi/Desktop/ML-Stock-Predictor/helper_functions.py:66: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df["income_growth"] = df.groupby("ticker")["net_income"].pct_change()

# %% [markdown]
# ## Run all the models with variations in Features and Horizons

# %%
features_map = {
    "raw": raw,
    "eng": eng,
    "fund": fund,
    "fund_eng": fund_eng
}

# %%
features_map
# Out:
# {'raw': ['ret', 'volume'],
#  'eng': ['mean_20',
#   'mean_60',
#   'vol_20',
#   'vol_60',
#   'mom_20',
#   'mom_60',
#   'ema_12',
#   'ema_26',
#   'ema_cross',
#   'skew_20',
#   'skew_60',
#   'kurt_20',
#   'kurt_60',
#   'vol_z'],
#  'fund': ['eps',
#   'profit_margin',
#   'revenue_growth',
#   'income_growth',
#   'gross_margin',
#   'operating_margin',
#   'sga_ratio',
#   'rd_ratio',
#   'cost_ratio',
#   'net_income_per_share',
#   'tax_burden',
#   'nonop_ratio',
#   'abnormal_ratio',
#   'revenue_per_share',
#   'da_ratio',
#   'interest_coverage',
#   'interest_burden'],
#  'fund_eng': ['eps',
#   'profit_margin',
#   'revenue_growth',
#   'income_growth',
#   'gross_margin',
#   'operating_margin',
#   'sga_ratio',
#   'rd_ratio',
#   'cost_ratio',
#   'net_income_per_share',
#   'tax_burden',
#   'nonop_ratio',
#   'abnormal_ratio',
#   'revenue_per_share',
#   'da_ratio',
#   'interest_coverage',
#   'interest_burden',
#   'mean_20',
#   'mean_60',
#   'vol_20',
#   'vol_60',
#   'mom_20',
#   'mom_60',
#   'ema_12',
#   'ema_26',
#   'ema_cross',
#   'skew_20',
#   'skew_60',
#   'kurt_20',
#   'kurt_60',
#   'vol_z']}

# %%
features_sets = ['raw', 'eng', 'fund', 'fund_eng']
targets = ['y_1', 'y_20', 'y_60']

res = []

for f, t in product(features_sets, targets):
    print(f, t, type(f), type(t))
    
    # FIX: force list
    features = list(features_map[f])

    data = hf.prune(df, features, t)

    train, val, test = hf.time_split(data)
    print(f, t)

    val_auc, val_acc, test_auc, test_acc = rp.run_random_baseline(train, val, test, features, t)

    res.append({
        "Horizon": t,
        "Features": f,
        "Val AUC": val_auc,
        "Val Accuracy": val_acc,
        "Test AUC": test_auc,
        "Test Accuracy": test_acc
    })

res
# Out:
# raw y_1 <class 'str'> <class 'str'>
# raw y_1
# raw y_20 <class 'str'> <class 'str'>
# raw y_20
# raw y_60 <class 'str'> <class 'str'>
# raw y_60
# eng y_1 <class 'str'> <class 'str'>
# eng y_1
# eng y_20 <class 'str'> <class 'str'>
# eng y_20
# eng y_60 <class 'str'> <class 'str'>
# eng y_60
# fund y_1 <class 'str'> <class 'str'>
# fund y_1
# fund y_20 <class 'str'> <class 'str'>
# fund y_20
# fund y_60 <class 'str'> <class 'str'>
# fund y_60
# fund_eng y_1 <class 'str'> <class 'str'>
# fund_eng y_1
# fund_eng y_20 <class 'str'> <class 'str'>
# fund_eng y_20
# fund_eng y_60 <class 'str'> <class 'str'>
# fund_eng y_60
# [{'Horizon': 'y_1',
#   'Features': 'raw',
#   'Val AUC': 0.5049348487574257,
#   'Val Accuracy': 0.5026333113890717,
#   'Test AUC': 0.5013900476286025,
#   'Test Accuracy': 0.499834528405957},
#  {'Horizon': 'y_20',
#   'Features': 'raw',
#   'Val AUC': 0.5013404591545769,
#   'Val Accuracy': 0.49871751979480317,
#   'Test AUC': 0.4970457994614314,
#   'Test Accuracy': 0.4934962996187486},
#  {'Horizon': 'y_60',
#   'Features': 'raw',
#   'Val AUC': 0.49509227774296466,
#   'Val Accuracy': 0.4921019255159691,
#   'Test AUC': 0.5097128437063754,
#   'Test Accuracy': 0.5041743970315399},
#  {'Horizon': 'y_1',
#   'Features': 'eng',
#   'Val AUC': 0.5024319079117537,
#   'Val Accuracy': 0.5096275798454976,
#   'Test AUC': 0.49530940745232716,
#   'Test Accuracy': 0.49907235621521334},
#  {'Horizon': 'y_20',
#   'Features': 'eng',
#   'Val AUC': 0.4904787854531263,
#   'Val Accuracy': 0.4910860896082571,
#   'Test AUC': 0.5206939353398536,
#   'Test Accuracy': 0.5166922260233573},
#  {'Horizon': 'y_60',
#   'Features': 'eng',
#   'Val AUC': 0.5029426298564531,
#   'Val Accuracy': 0.49842079689018465,
#   'Test AUC': 0.5101973751771447,
#   'Test Accuracy': 0.5034828302578517},
#  {'Horizon': 'y_1',
#   'Features': 'fund',
#   'Val AUC': 0.4924943508387012,
#   'Val Accuracy': 0.48864864864864865,
#   'Test AUC': 0.48200931013431014,
#   'Test Accuracy': 0.4923913043478261},
#  {'Horizon': 'y_20',
#   'Features': 'fund',
#   'Val AUC': 0.5093837309655809,
#   'Val Accuracy': 0.5131868131868131,
#   'Test AUC': 0.4957036348534588,
#   'Test Accuracy': 0.5032967032967033},
#  {'Horizon': 'y_60',
#   'Features': 'fund',
#   'Val AUC': 0.5129937713160297,
#   'Val Accuracy': 0.5159090909090909,
#   'Test AUC': 0.4949803258191446,
#   'Test Accuracy': 0.4954545454545455},
#  {'Horizon': 'y_1',
#   'Features': 'fund_eng',
#   'Val AUC': 0.4856342119529084,
#   'Val Accuracy': 0.47796610169491527,
#   'Test AUC': 0.47582227230987556,
#   'Test Accuracy': 0.475},
#  {'Horizon': 'y_20',
#   'Features': 'fund_eng',
#   'Val AUC': 0.4974708994708995,
#   'Val Accuracy': 0.5057471264367817,
#   'Test AUC': 0.49721095890410955,
#   'Test Accuracy': 0.4982658959537572},
#  {'Horizon': 'y_60',
#   'Features': 'fund_eng',
#   'Val AUC': 0.4962392051258241,
#   'Val Accuracy': 0.49642857142857144,
#   'Test AUC': 0.5049430587577727,
#   'Test Accuracy': 0.5041916167664671}]

# %%
res_df = pd.DataFrame(res)
val_acc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Val Accuracy")

val_acc_df = val_acc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

val_acc_df = val_acc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

val_acc_st = (
    val_acc_df.style
      .set_caption("Table 1: Random Predictor - Summary Validation Accuracy")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)

#dfi.export(test_st, "random_forest_table_test.png", table_conversion="matplotlib")
dfi.export(val_acc_st, "random_predictor_table_validation_accuracy.png", table_conversion="matplotlib")

# %%
val_acc_st
# Out:
# <style type="text/css">
# #T_ea6b0 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_ea6b0 th {
#   padding: 10px;
# }
# #T_ea6b0  td {
#   padding: 10px;
# }
# #T_ea6b0 th {
#   font-size: 12pt;
# }
# #T_ea6b0 td {
#   font-size: 11pt;
# }
# #T_ea6b0_row0_col0, #T_ea6b0_row0_col1, #T_ea6b0_row0_col2, #T_ea6b0_row1_col0, #T_ea6b0_row1_col1, #T_ea6b0_row1_col2, #T_ea6b0_row2_col0, #T_ea6b0_row2_col1, #T_ea6b0_row2_col2, #T_ea6b0_row3_col0, #T_ea6b0_row3_col1, #T_ea6b0_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_ea6b0">
#   <caption>Table 1: Random Predictor - Summary Validation Accuracy</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_ea6b0_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_ea6b0_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_ea6b0_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea6b0_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_ea6b0_row0_col0" class="data row0 col0" >0.5096</td>
#       <td id="T_ea6b0_row0_col1" class="data row0 col1" >0.4911</td>
#       <td id="T_ea6b0_row0_col2" class="data row0 col2" >0.4984</td>
#     </tr>
#     <tr>
#       <th id="T_ea6b0_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_ea6b0_row1_col0" class="data row1 col0" >0.4886</td>
#       <td id="T_ea6b0_row1_col1" class="data row1 col1" >0.5132</td>
#       <td id="T_ea6b0_row1_col2" class="data row1 col2" >0.5159</td>
#     </tr>
#     <tr>
#       <th id="T_ea6b0_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_ea6b0_row2_col0" class="data row2 col0" >0.4780</td>
#       <td id="T_ea6b0_row2_col1" class="data row2 col1" >0.5057</td>
#       <td id="T_ea6b0_row2_col2" class="data row2 col2" >0.4964</td>
#     </tr>
#     <tr>
#       <th id="T_ea6b0_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_ea6b0_row3_col0" class="data row3 col0" >0.5026</td>
#       <td id="T_ea6b0_row3_col1" class="data row3 col1" >0.4987</td>
#       <td id="T_ea6b0_row3_col2" class="data row3 col2" >0.4921</td>
#     </tr>
#   </tbody>
# </table>

# %%
res_df = pd.DataFrame(res)
val_auc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Val AUC")

val_auc_df = val_auc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

val_auc_df = val_auc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

val_auc_st = (
    val_auc_df.style
      .set_caption("Table 1: Random Predictor - Summary Validation AUC")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)

dfi.export(val_auc_st, "random_predictor_table_validation_AUC.png", table_conversion="matplotlib")

# %%
val_auc_st
# Out:
# <style type="text/css">
# #T_6d66f table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_6d66f th {
#   padding: 10px;
# }
# #T_6d66f  td {
#   padding: 10px;
# }
# #T_6d66f th {
#   font-size: 12pt;
# }
# #T_6d66f td {
#   font-size: 11pt;
# }
# #T_6d66f_row0_col0, #T_6d66f_row0_col1, #T_6d66f_row0_col2, #T_6d66f_row1_col0, #T_6d66f_row1_col1, #T_6d66f_row1_col2, #T_6d66f_row2_col0, #T_6d66f_row2_col1, #T_6d66f_row2_col2, #T_6d66f_row3_col0, #T_6d66f_row3_col1, #T_6d66f_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_6d66f">
#   <caption>Table 1: Random Predictor - Summary Validation AUC</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_6d66f_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_6d66f_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_6d66f_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d66f_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_6d66f_row0_col0" class="data row0 col0" >0.5024</td>
#       <td id="T_6d66f_row0_col1" class="data row0 col1" >0.4905</td>
#       <td id="T_6d66f_row0_col2" class="data row0 col2" >0.5029</td>
#     </tr>
#     <tr>
#       <th id="T_6d66f_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_6d66f_row1_col0" class="data row1 col0" >0.4925</td>
#       <td id="T_6d66f_row1_col1" class="data row1 col1" >0.5094</td>
#       <td id="T_6d66f_row1_col2" class="data row1 col2" >0.5130</td>
#     </tr>
#     <tr>
#       <th id="T_6d66f_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_6d66f_row2_col0" class="data row2 col0" >0.4856</td>
#       <td id="T_6d66f_row2_col1" class="data row2 col1" >0.4975</td>
#       <td id="T_6d66f_row2_col2" class="data row2 col2" >0.4962</td>
#     </tr>
#     <tr>
#       <th id="T_6d66f_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_6d66f_row3_col0" class="data row3 col0" >0.5049</td>
#       <td id="T_6d66f_row3_col1" class="data row3 col1" >0.5013</td>
#       <td id="T_6d66f_row3_col2" class="data row3 col2" >0.4951</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_acc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Test Accuracy")
test_acc_df = test_acc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

test_acc_df = test_acc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

test_acc_st = (
    test_acc_df.style
      .set_caption("Table 2: Random Predictor - Summary Testing Accuracy")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)
dfi.export(test_acc_st, "random_predictor_table_test_accuracy.png", table_conversion="matplotlib")

# %%
test_acc_st
# Out:
# <style type="text/css">
# #T_1fb6b table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_1fb6b th {
#   padding: 10px;
# }
# #T_1fb6b  td {
#   padding: 10px;
# }
# #T_1fb6b th {
#   font-size: 12pt;
# }
# #T_1fb6b td {
#   font-size: 11pt;
# }
# #T_1fb6b_row0_col0, #T_1fb6b_row0_col1, #T_1fb6b_row0_col2, #T_1fb6b_row1_col0, #T_1fb6b_row1_col1, #T_1fb6b_row1_col2, #T_1fb6b_row2_col0, #T_1fb6b_row2_col1, #T_1fb6b_row2_col2, #T_1fb6b_row3_col0, #T_1fb6b_row3_col1, #T_1fb6b_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_1fb6b">
#   <caption>Table 2: Random Predictor - Summary Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_1fb6b_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_1fb6b_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_1fb6b_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fb6b_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_1fb6b_row0_col0" class="data row0 col0" >0.4991</td>
#       <td id="T_1fb6b_row0_col1" class="data row0 col1" >0.5167</td>
#       <td id="T_1fb6b_row0_col2" class="data row0 col2" >0.5035</td>
#     </tr>
#     <tr>
#       <th id="T_1fb6b_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_1fb6b_row1_col0" class="data row1 col0" >0.4924</td>
#       <td id="T_1fb6b_row1_col1" class="data row1 col1" >0.5033</td>
#       <td id="T_1fb6b_row1_col2" class="data row1 col2" >0.4955</td>
#     </tr>
#     <tr>
#       <th id="T_1fb6b_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_1fb6b_row2_col0" class="data row2 col0" >0.4750</td>
#       <td id="T_1fb6b_row2_col1" class="data row2 col1" >0.4983</td>
#       <td id="T_1fb6b_row2_col2" class="data row2 col2" >0.5042</td>
#     </tr>
#     <tr>
#       <th id="T_1fb6b_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_1fb6b_row3_col0" class="data row3 col0" >0.4998</td>
#       <td id="T_1fb6b_row3_col1" class="data row3 col1" >0.4935</td>
#       <td id="T_1fb6b_row3_col2" class="data row3 col2" >0.5042</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_auc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Test AUC")
test_auc_df = test_auc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

test_auc_df = test_auc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

test_auc_st = (
    test_auc_df.style
      .set_caption("Table 2: Random Predictor - Summary Testing AUC")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)
dfi.export(test_auc_st, "random_predictor_table_test_AUC.png", table_conversion="matplotlib")

# %%
test_auc_st
# Out:
# <style type="text/css">
# #T_72484 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_72484 th {
#   padding: 10px;
# }
# #T_72484  td {
#   padding: 10px;
# }
# #T_72484 th {
#   font-size: 12pt;
# }
# #T_72484 td {
#   font-size: 11pt;
# }
# #T_72484_row0_col0, #T_72484_row0_col1, #T_72484_row0_col2, #T_72484_row1_col0, #T_72484_row1_col1, #T_72484_row1_col2, #T_72484_row2_col0, #T_72484_row2_col1, #T_72484_row2_col2, #T_72484_row3_col0, #T_72484_row3_col1, #T_72484_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_72484">
#   <caption>Table 2: Random Predictor - Summary Testing AUC</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_72484_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_72484_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_72484_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72484_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_72484_row0_col0" class="data row0 col0" >0.4953</td>
#       <td id="T_72484_row0_col1" class="data row0 col1" >0.5207</td>
#       <td id="T_72484_row0_col2" class="data row0 col2" >0.5102</td>
#     </tr>
#     <tr>
#       <th id="T_72484_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_72484_row1_col0" class="data row1 col0" >0.4820</td>
#       <td id="T_72484_row1_col1" class="data row1 col1" >0.4957</td>
#       <td id="T_72484_row1_col2" class="data row1 col2" >0.4950</td>
#     </tr>
#     <tr>
#       <th id="T_72484_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_72484_row2_col0" class="data row2 col0" >0.4758</td>
#       <td id="T_72484_row2_col1" class="data row2 col1" >0.4972</td>
#       <td id="T_72484_row2_col2" class="data row2 col2" >0.5049</td>
#     </tr>
#     <tr>
#       <th id="T_72484_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_72484_row3_col0" class="data row3 col0" >0.5014</td>
#       <td id="T_72484_row3_col1" class="data row3 col1" >0.4970</td>
#       <td id="T_72484_row3_col2" class="data row3 col2" >0.5097</td>
#     </tr>
#   </tbody>
# </table>
