# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch import nn

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras import layers, models

# %%
import helper_functions as hf
import Models

# %% [markdown]
# # Load Data

# %%
df = hf.load_data()

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Fundamental features

# %%
df = hf.create_fundamental_features(df)
# Out:
# /Users/evi/Desktop/ML-Stock-Predictor/helper_functions.py:55: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['revenue_growth'] = df.groupby('ticker')['revenue'].pct_change()
# /Users/evi/Desktop/ML-Stock-Predictor/helper_functions.py:57: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df["income_growth"] = df.groupby("ticker")["net_income"].pct_change()

# %% [markdown]
# ## Engineered Features

# %%
df = hf.create_engineered_features(df)
df.columns
# Out:
# Index(['index_x', 'ticker', 'simfinid_x', 'date', 'open', 'high', 'low',
#        'close', 'adj_close', 'volume', 'dividend', 'shares_outstanding',
#        'index_y', 'simfinid_y', 'currency', 'fiscal_year', 'fiscal_period',
#        'report_date', 'publish_date', 'restated_date', 'shares_basic',
#        'shares_diluted', 'revenue', 'cost_of_revenue', 'gross_profit',
#        'operating_expenses', 'selling_general_&_administrative',
#        'research_&_development', 'depreciation_&_amortization',
#        'operating_income_loss', 'non-operating_income_loss',
#        'interest_expense_net', 'pretax_income_loss_adj',
#        'abnormal_gains_losses', 'pretax_income_loss',
#        'income_tax_expense_benefit_net',
#        'income_loss_from_continuing_operations',
#        'net_extraordinary_gains_losses', 'net_income', 'net_income_common',
#        'ret', 'eps', 'profit_margin', 'revenue_growth', 'income_growth',
#        'gross_margin', 'operating_margin', 'sga_ratio', 'rd_ratio',
#        'cost_ratio', 'net_income_per_share', 'tax_burden', 'nonop_ratio',
#        'abnormal_ratio', 'revenue_per_share', 'da_ratio', 'interest_coverage',
#        'interest_burden', 'mean_20', 'mean_60', 'vol_20', 'vol_60', 'mom_5',
#        'mom_20', 'mom_60', 'ema_12', 'ema_26', 'ema_cross', 'skew_20',
#        'skew_60', 'kurt_20', 'kurt_60', 'vol_z'],
#       dtype='object')

# %% [markdown]
# <h3 style="color:red">Todo: generate more features</h3>

# %% [markdown]
# Select features

# %%
raw = ['ret']
eng = [
    'mean_20', 'mean_60',
    'vol_20', 'vol_60',
    'mom_5', 'mom_20', 'mom_60',
    'ema_12', 'ema_26', 'ema_cross',
    'skew_20', 'skew_60',
    'kurt_20', 'kurt_60',
    'vol_z'
]
fund = [
    'eps',
    'profit_margin',
    'revenue_growth',
    'income_growth',
    'gross_margin',
    'operating_margin',
    'sga_ratio',
    'rd_ratio',
    'cost_ratio',
    'net_income_per_share',
    'tax_burden',
    'nonop_ratio',
    'abnormal_ratio',
    'revenue_per_share',
    'da_ratio',
    'interest_coverage',
    'interest_burden'
]
fund_eng = fund + eng

# %% [markdown]
# # Feature Selection

# %%
rt = df.pivot(index='date', columns='ticker', values='ret')
rt
# Out:
# ticker          AAPL       ABT      ADBE      AMGN      AMZN       AXP  \
# date
# 2019-12-23       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-12-24  0.000876 -0.000764  0.002098 -0.002851 -0.002119  0.002001
# 2019-12-26  0.019974  0.000000  0.004732 -0.001774  0.044489  0.005382
# 2019-12-27 -0.000429  0.001274 -0.001238 -0.001531  0.000535 -0.001813
# 2019-12-30  0.005863 -0.006870 -0.007407 -0.005242 -0.012301 -0.007093
# ...              ...       ...       ...       ...       ...       ...
# 2024-11-19  0.001145 -0.001911  0.000200  0.004266  0.014427  0.000035
# 2024-11-20  0.003168 -0.010267 -0.000220  0.028309 -0.008455  0.007541
# 2024-11-21 -0.002105  0.011429  0.009890  0.007052 -0.022181  0.018412
# 2024-11-22  0.005890  0.004346  0.015284  0.015949 -0.006351  0.028327
# 2024-11-25  0.013065  0.003116  0.012848 -0.001775  0.021966  0.012951
#
# ticker           BAC       BMY     CMCSA      COST  ...       RTX      SBUX  \
# date                                                ...
# 2019-12-23       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2019-12-24  0.001639 -0.000793  0.009595  0.003130  ... -0.001544  0.003367
# 2019-12-26  0.008508  0.012691  0.010032  0.005126  ...  0.007577 -0.005033
# 2019-12-27 -0.004867  0.002937  0.002875 -0.005506  ... -0.002916  0.000519
# 2019-12-30 -0.005543 -0.006443  0.001564  0.003530  ... -0.002617 -0.007778
# ...              ...       ...       ...       ...  ...       ...       ...
# 2024-11-19 -0.006572  0.025139 -0.015927  0.011577  ... -0.003655 -0.020354
# 2024-11-20 -0.007718 -0.005950  0.015939 -0.002226  ...  0.001621 -0.000940
# 2024-11-21  0.008889  0.005986  0.011827  0.029698  ...  0.011582  0.018288
# 2024-11-22  0.011454  0.010999 -0.000716  0.008751  ...  0.002021  0.024425
# 2024-11-25  0.010671 -0.001605 -0.006207 -0.003232  ... -0.017560 -0.006412
#
# ticker             T      TSLA       TXN       UNH         V        VZ  \
# date
# 2019-12-23       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-12-24 -0.002459  0.014311 -0.000185 -0.001856  0.002621 -0.002067
# 2019-12-26  0.004931  0.013404 -0.000369  0.003756  0.008456  0.000230
# 2019-12-27  0.001963 -0.001392  0.000739  0.001112  0.001214  0.003911
# 2019-12-30 -0.004897 -0.036250 -0.007105 -0.007180 -0.008264 -0.005270
# ...              ...       ...       ...       ...       ...       ...
# 2024-11-19 -0.010909  0.021432 -0.029504 -0.021454 -0.000968 -0.007589
# 2024-11-20  0.004136 -0.011474 -0.014328  0.040732 -0.014306  0.006882
# 2024-11-21  0.006407 -0.006988  0.000052 -0.005003  0.008158  0.006582
# 2024-11-22  0.009095  0.038040 -0.000990 -0.011082  0.000065  0.015342
# 2024-11-25 -0.003605 -0.039624  0.024875  0.025318  0.010561  0.019321
#
# ticker           WMT       XOM
# date
# 2019-12-23       NaN       NaN
# 2019-12-24  0.004106 -0.003761
# 2019-12-26  0.000000  0.001510
# 2019-12-27  0.000818 -0.003392
# 2019-12-30 -0.001634 -0.005862
# ...              ...       ...
# 2024-11-19  0.029903 -0.013961
# 2024-11-20  0.006763  0.014246
# 2024-11-21  0.013899  0.013442
# 2024-11-22  0.023189 -0.001190
# 2024-11-25 -0.010383 -0.014897
#
# [1240 rows x 49 columns]

# %% [markdown]
# <h3 style="color:red">Todo: save clean data for easy access</h3>

# %% [markdown]
# # Binary Labels

# %%
# input is the dataframe and the horizon we are looking at
df = hf.create_binary_labels(df,1)
# Out:
# /Users/evi/Desktop/ML-Stock-Predictor/helper_functions.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'y_{h}'] = (df[f'cumret_{h}'] > 0).astype(int)

# %% [markdown]
# # Modeling

# %%
# split sets
# inputs are dataframe, fraction in training, fraction in validation, column we're splitting at
train,val,test = hf.time_split(df,0.7,0.15,'date')

# %% [markdown]
# ## Standarization

# %%
X_train = train[fund_eng]
X_val = val[fund_eng]
X_test = test[fund_eng]

scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_val   = scaler.transform(X_val)
X_test  = scaler.transform(X_test)

# %% [markdown]
# ## Training

# %% [markdown]
# <h3 style="color:red">Note: apply basic logistic regression as starting point - ideally do LSTM later</h3>

# %% [markdown]
# # Logistic Regression

# %%
# pick your feature set
FEATURES = fund_eng
TARGET = "y_1"

model, val_acc, test_acc = Models.run_logistic_regression(train, val, test, FEATURES, TARGET)
# Out:
# Validation Accuracy: 0.6043010752688172
# Test Accuracy: 0.6162162162162163

# %% [markdown]
# # LSTM

# %%
SEQ_LEN = 30
TARGET = "y_1"
FEATURES = fund_eng

model, history, test_acc = Models.run_lstm(train, val, test, FEATURES, TARGET, seq_len=SEQ_LEN)
# Out:
# Shapes:
# Train: (3060, 30, 32) (3060,)
# Val:   (780, 30, 32) (780,)
# Test:  (775, 30, 32) (775,)
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5159 - loss: 0.7007 - val_accuracy: 0.5051 - val_loss: 0.6982
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5322 - loss: 0.6895 - val_accuracy: 0.4897 - val_loss: 0.7001
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5434 - loss: 0.6853 - val_accuracy: 0.4936 - val_loss: 0.7153
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5520 - loss: 0.6911 - val_accuracy: 0.4795 - val_loss: 0.7083
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5326 - loss: 0.6961 - val_accuracy: 0.4846 - val_loss: 0.7111
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5346 - loss: 0.6871 - val_accuracy: 0.4923 - val_loss: 0.7082
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5692 - loss: 0.6782 - val_accuracy: 0.4897 - val_loss: 0.7161
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5761 - loss: 0.6733 - val_accuracy: 0.4808 - val_loss: 0.7215
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5866 - loss: 0.6717 - val_accuracy: 0.4897 - val_loss: 0.7252
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5960 - loss: 0.6709 - val_accuracy: 0.4795 - val_loss: 0.7262
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5944 - loss: 0.6670 - val_accuracy: 0.4744 - val_loss: 0.7322
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5845 - loss: 0.6721 - val_accuracy: 0.4821 - val_loss: 0.7239
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5799 - loss: 0.6710 - val_accuracy: 0.4795 - val_loss: 0.7313
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6068 - loss: 0.6619 - val_accuracy: 0.4846 - val_loss: 0.7417
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6040 - loss: 0.6673 - val_accuracy: 0.4910 - val_loss: 0.7380
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5871 - loss: 0.6706 - val_accuracy: 0.4923 - val_loss: 0.7242
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5838 - loss: 0.6776 - val_accuracy: 0.4808 - val_loss: 0.7481
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5893 - loss: 0.6673 - val_accuracy: 0.4718 - val_loss: 0.7242
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5969 - loss: 0.6629 - val_accuracy: 0.4833 - val_loss: 0.7224
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6128 - loss: 0.6524 - val_accuracy: 0.4731 - val_loss: 0.7294
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4901 - loss: 0.7259
# Test accuracy: 0.4748387038707733
