# %% [markdown]
# # MLP for all horizons

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch import nn

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras import layers, models

# %%
import helper_functions as hf
import MLP_Model as mlp
import dataframe_image as dfi
from itertools import product

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from itertools import product
from sklearn.metrics import classification_report

# %% [markdown]
# ## Load Data

# %%
df = hf.load_data()
df = hf.create_engineered_plus_fundamental_features(df)
df = hf.create_binary_labels(df,[1,20,60])

raw = ['ret','volume']
eng = [
    'mean_20', 'mean_60',
    'vol_20', 'vol_60',
    'mom_20', 'mom_60',
    'ema_12', 'ema_26', 'ema_cross',
    'skew_20', 'skew_60',
    'kurt_20', 'kurt_60',
    'vol_z'
]
fund = [
    'eps',
    'profit_margin',
    'revenue_growth',
    'income_growth',
    'gross_margin',
    'operating_margin',
    'sga_ratio',
    'rd_ratio',
    'cost_ratio',
    'net_income_per_share',
    'tax_burden',
    'nonop_ratio',
    'abnormal_ratio',
    'revenue_per_share',
    'da_ratio',
    'interest_coverage',
    'interest_burden'
]

fund_eng = fund + eng 

#rt = df.pivot(index='date', columns='ticker', values='ret')
# Out:
# /Users/evi/Desktop/ML-Stock-Predictor/helper_functions.py:64: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['revenue_growth'] = df.groupby('ticker')['revenue'].pct_change()
# /Users/evi/Desktop/ML-Stock-Predictor/helper_functions.py:66: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df["income_growth"] = df.groupby("ticker")["net_income"].pct_change()

# %% [markdown]
# # Modeling: MLP Model

# %% [markdown]
# ## Run all the models with variations in Features and Horizons

# %%
features_map = {
    "raw": raw,
    "eng": eng,
    "fund": fund,
    "fund_eng": fund_eng
}

# %%
features_sets = ['raw', 'eng', 'fund', 'fund_eng']
targets = ['y_1', 'y_20', 'y_60']

#features_sets = ['raw']
#targets = ['y_1']

res = []

for f, t in product(features_sets, targets):
    print(f, t, type(f), type(t))
    features = features_map[f]
    data = hf.prune(df, features, t)

    train, val, test = hf.time_split(data)
    print(f, t)
    val_auc, val_acc, test_auc, test_acc = mlp.run_optimize_eval_MLP(train, val, test, features, t)

    res.append({
        "Horizon": t,
        "Features": f,
        "Val AUC": val_auc,
        "Val Accuracy": val_acc,
        "Test AUC": test_auc,
        "Test Accuracy": test_acc
    })
res
# Out:
# raw y_1 <class 'str'> <class 'str'>
# raw y_1
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5008 - auc: 0.5010 - loss: 0.6960 - val_accuracy: 0.5249 - val_auc: 0.4949 - val_loss: 0.6925
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.5182 - auc: 0.5160 - loss: 0.6922 - val_accuracy: 0.5247 - val_auc: 0.4978 - val_loss: 0.6922
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.5185 - auc: 0.5087 - loss: 0.6922 - val_accuracy: 0.5268 - val_auc: 0.4955 - val_loss: 0.6923
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - accuracy: 0.5167 - auc: 0.5141 - loss: 0.6921 - val_accuracy: 0.5296 - val_auc: 0.4992 - val_loss: 0.6917
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - accuracy: 0.5200 - auc: 0.5120 - loss: 0.6920 - val_accuracy: 0.5267 - val_auc: 0.4976 - val_loss: 0.6923
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.5168 - auc: 0.5193 - loss: 0.6918 - val_accuracy: 0.5314 - val_auc: 0.5016 - val_loss: 0.6916
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.5231 - auc: 0.5107 - loss: 0.6920 - val_accuracy: 0.5266 - val_auc: 0.5005 - val_loss: 0.6927
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5205 - auc: 0.5116 - loss: 0.6919 - val_accuracy: 0.5275 - val_auc: 0.5003 - val_loss: 0.6926
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5209 - auc: 0.5156 - loss: 0.6918 - val_accuracy: 0.5290 - val_auc: 0.5046 - val_loss: 0.6920
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5190 - auc: 0.5115 - loss: 0.6921 - val_accuracy: 0.5291 - val_auc: 0.5004 - val_loss: 0.6921
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5227 - auc: 0.5165 - loss: 0.6915 - val_accuracy: 0.5259 - val_auc: 0.5028 - val_loss: 0.6923
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5118 - auc: 0.5100 - loss: 0.6979 - val_accuracy: 0.5315 - val_auc: 0.5030 - val_loss: 0.6924
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5237 - auc: 0.5153 - loss: 0.6920 - val_accuracy: 0.5319 - val_auc: 0.5007 - val_loss: 0.6922
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5203 - auc: 0.5165 - loss: 0.6923 - val_accuracy: 0.5311 - val_auc: 0.5009 - val_loss: 0.6923
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5185 - auc: 0.5125 - loss: 0.6926 - val_accuracy: 0.5292 - val_auc: 0.4975 - val_loss: 0.6926
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5167 - auc: 0.5192 - loss: 0.6919 - val_accuracy: 0.5317 - val_auc: 0.4993 - val_loss: 0.6923
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5241 - auc: 0.5156 - loss: 0.6921 - val_accuracy: 0.5306 - val_auc: 0.5024 - val_loss: 0.6926
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5218 - auc: 0.5113 - loss: 0.6919 - val_accuracy: 0.5264 - val_auc: 0.5016 - val_loss: 0.6926
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5121 - auc: 0.5108 - loss: 0.6995 - val_accuracy: 0.5291 - val_auc: 0.4978 - val_loss: 0.6943
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5215 - auc: 0.5138 - loss: 0.6942 - val_accuracy: 0.5273 - val_auc: 0.4998 - val_loss: 0.6942
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5201 - auc: 0.5132 - loss: 0.6941 - val_accuracy: 0.5253 - val_auc: 0.4981 - val_loss: 0.6942
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.5187 - auc: 0.5128 - loss: 0.6933 - val_accuracy: 0.5281 - val_auc: 0.4981 - val_loss: 0.6934
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - accuracy: 0.5223 - auc: 0.5207 - loss: 0.6929 - val_accuracy: 0.5280 - val_auc: 0.4991 - val_loss: 0.6933
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.5218 - auc: 0.5145 - loss: 0.6929 - val_accuracy: 0.5282 - val_auc: 0.4976 - val_loss: 0.6929
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - accuracy: 0.5215 - auc: 0.5130 - loss: 0.6929 - val_accuracy: 0.5271 - val_auc: 0.4970 - val_loss: 0.6933
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - accuracy: 0.5206 - auc: 0.5103 - loss: 0.6929 - val_accuracy: 0.5283 - val_auc: 0.4951 - val_loss: 0.6934
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.5204 - auc: 0.5192 - loss: 0.6922 - val_accuracy: 0.5304 - val_auc: 0.4987 - val_loss: 0.6924
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.5246 - auc: 0.5187 - loss: 0.6919 - val_accuracy: 0.5284 - val_auc: 0.4975 - val_loss: 0.6927
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.5189 - auc: 0.5136 - loss: 0.6925 - val_accuracy: 0.5300 - val_auc: 0.4998 - val_loss: 0.6923
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.5274 - auc: 0.5180 - loss: 0.6916 - val_accuracy: 0.5269 - val_auc: 0.4950 - val_loss: 0.6931
# Epoch 13/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.5187 - auc: 0.5130 - loss: 0.6927 - val_accuracy: 0.5274 - val_auc: 0.4977 - val_loss: 0.6924
# Epoch 14/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.5158 - auc: 0.5137 - loss: 0.6924 - val_accuracy: 0.5284 - val_auc: 0.4961 - val_loss: 0.6923
# Epoch 15/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.5190 - auc: 0.5120 - loss: 0.6923 - val_accuracy: 0.5284 - val_auc: 0.4957 - val_loss: 0.6925
# Epoch 16/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.5202 - auc: 0.5161 - loss: 0.6923 - val_accuracy: 0.5287 - val_auc: 0.4951 - val_loss: 0.6922
# Epoch 17/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.5195 - auc: 0.5136 - loss: 0.6923 - val_accuracy: 0.5280 - val_auc: 0.4952 - val_loss: 0.6924
# Epoch 18/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - accuracy: 0.5168 - auc: 0.5125 - loss: 0.6925 - val_accuracy: 0.5262 - val_auc: 0.4971 - val_loss: 0.6925
# Epoch 19/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5163 - auc: 0.5145 - loss: 0.6925 - val_accuracy: 0.5271 - val_auc: 0.4948 - val_loss: 0.6925
# Epoch 20/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5187 - auc: 0.5151 - loss: 0.6918 - val_accuracy: 0.5296 - val_auc: 0.4936 - val_loss: 0.6921
# Epoch 21/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5204 - auc: 0.5167 - loss: 0.6920 - val_accuracy: 0.5267 - val_auc: 0.4950 - val_loss: 0.6926
# Epoch 22/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5189 - auc: 0.5109 - loss: 0.6920 - val_accuracy: 0.5270 - val_auc: 0.4939 - val_loss: 0.6925
# Epoch 23/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5224 - auc: 0.5185 - loss: 0.6918 - val_accuracy: 0.5300 - val_auc: 0.4989 - val_loss: 0.6922
# Epoch 24/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5215 - auc: 0.5172 - loss: 0.6918 - val_accuracy: 0.5275 - val_auc: 0.4933 - val_loss: 0.6923
# Epoch 25/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5181 - auc: 0.5177 - loss: 0.6921 - val_accuracy: 0.5275 - val_auc: 0.4958 - val_loss: 0.6924
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5107 - auc: 0.5014 - loss: 0.6952 - val_accuracy: 0.5069 - val_auc: 0.4972 - val_loss: 0.6930
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5141 - auc: 0.5149 - loss: 0.6925 - val_accuracy: 0.5250 - val_auc: 0.4984 - val_loss: 0.6924
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5184 - auc: 0.5157 - loss: 0.6919 - val_accuracy: 0.5213 - val_auc: 0.5023 - val_loss: 0.6924
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5141 - auc: 0.5124 - loss: 0.6921 - val_accuracy: 0.5285 - val_auc: 0.5012 - val_loss: 0.6920
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5133 - auc: 0.5159 - loss: 0.6919 - val_accuracy: 0.5306 - val_auc: 0.4989 - val_loss: 0.6919
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5215 - auc: 0.5187 - loss: 0.6918 - val_accuracy: 0.5285 - val_auc: 0.5018 - val_loss: 0.6919
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5240 - auc: 0.5192 - loss: 0.6914 - val_accuracy: 0.5262 - val_auc: 0.4998 - val_loss: 0.6924
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5179 - auc: 0.5157 - loss: 0.6917 - val_accuracy: 0.5271 - val_auc: 0.4993 - val_loss: 0.6920
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5195 - auc: 0.5174 - loss: 0.6917 - val_accuracy: 0.5278 - val_auc: 0.5025 - val_loss: 0.6919
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5222 - auc: 0.5129 - loss: 0.6919 - val_accuracy: 0.5257 - val_auc: 0.5022 - val_loss: 0.6924
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5186 - auc: 0.5172 - loss: 0.6918 - val_accuracy: 0.5282 - val_auc: 0.4985 - val_loss: 0.6921
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.5167 - auc: 0.5130 - loss: 0.6922 - val_accuracy: 0.5258 - val_auc: 0.5000 - val_loss: 0.6923
# Epoch 13/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.5221 - auc: 0.5190 - loss: 0.6915 - val_accuracy: 0.5271 - val_auc: 0.5036 - val_loss: 0.6921
# Epoch 14/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.5145 - auc: 0.5118 - loss: 0.6922 - val_accuracy: 0.5283 - val_auc: 0.5003 - val_loss: 0.6920
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 225us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5127 - auc: 0.5106 - loss: 0.6945 - val_accuracy: 0.5301 - val_auc: 0.5003 - val_loss: 0.6926
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.5208 - auc: 0.5185 - loss: 0.6923 - val_accuracy: 0.5301 - val_auc: 0.5021 - val_loss: 0.6926
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.5241 - auc: 0.5136 - loss: 0.6922 - val_accuracy: 0.5292 - val_auc: 0.5001 - val_loss: 0.6924
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.5171 - auc: 0.5100 - loss: 0.6927 - val_accuracy: 0.5332 - val_auc: 0.5018 - val_loss: 0.6922
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.5220 - auc: 0.5158 - loss: 0.6923 - val_accuracy: 0.5296 - val_auc: 0.4991 - val_loss: 0.6926
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.5222 - auc: 0.5100 - loss: 0.6923 - val_accuracy: 0.5289 - val_auc: 0.4998 - val_loss: 0.6927
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - accuracy: 0.5215 - auc: 0.5209 - loss: 0.6919 - val_accuracy: 0.5308 - val_auc: 0.5015 - val_loss: 0.6920
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5260 - auc: 0.5190 - loss: 0.6915 - val_accuracy: 0.5321 - val_auc: 0.5021 - val_loss: 0.6924
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5223 - auc: 0.5207 - loss: 0.6918 - val_accuracy: 0.5303 - val_auc: 0.5007 - val_loss: 0.6926
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5214 - auc: 0.5155 - loss: 0.6922 - val_accuracy: 0.5316 - val_auc: 0.5001 - val_loss: 0.6923
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5250 - auc: 0.5148 - loss: 0.6917 - val_accuracy: 0.5295 - val_auc: 0.4989 - val_loss: 0.6926
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5246 - auc: 0.5169 - loss: 0.6916 - val_accuracy: 0.5295 - val_auc: 0.4998 - val_loss: 0.6925
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5080 - auc: 0.4977 - loss: 0.6991 - val_accuracy: 0.4952 - val_auc: 0.4921 - val_loss: 0.6968
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5143 - auc: 0.5177 - loss: 0.6954 - val_accuracy: 0.5078 - val_auc: 0.4950 - val_loss: 0.6954
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5134 - auc: 0.5155 - loss: 0.6947 - val_accuracy: 0.5286 - val_auc: 0.4953 - val_loss: 0.6945
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.5189 - auc: 0.5164 - loss: 0.6942 - val_accuracy: 0.5267 - val_auc: 0.4951 - val_loss: 0.6943
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5198 - auc: 0.5149 - loss: 0.6940 - val_accuracy: 0.5280 - val_auc: 0.4998 - val_loss: 0.6937
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5196 - auc: 0.5137 - loss: 0.6935 - val_accuracy: 0.5306 - val_auc: 0.5028 - val_loss: 0.6933
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5229 - auc: 0.5188 - loss: 0.6931 - val_accuracy: 0.5284 - val_auc: 0.4974 - val_loss: 0.6936
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5173 - auc: 0.5148 - loss: 0.6934 - val_accuracy: 0.5285 - val_auc: 0.4986 - val_loss: 0.6934
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5221 - auc: 0.5201 - loss: 0.6927 - val_accuracy: 0.5283 - val_auc: 0.4997 - val_loss: 0.6933
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5223 - auc: 0.5159 - loss: 0.6926 - val_accuracy: 0.5272 - val_auc: 0.5036 - val_loss: 0.6932
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5208 - auc: 0.5144 - loss: 0.6927 - val_accuracy: 0.5285 - val_auc: 0.4989 - val_loss: 0.6929
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5241 - auc: 0.5171 - loss: 0.6924 - val_accuracy: 0.5282 - val_auc: 0.5017 - val_loss: 0.6931
# Epoch 13/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5216 - auc: 0.5122 - loss: 0.6925 - val_accuracy: 0.5292 - val_auc: 0.5011 - val_loss: 0.6929
# Epoch 14/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.5178 - auc: 0.5171 - loss: 0.6929 - val_accuracy: 0.5282 - val_auc: 0.4995 - val_loss: 0.6927
# Epoch 15/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.5168 - auc: 0.5180 - loss: 0.6928 - val_accuracy: 0.5287 - val_auc: 0.5009 - val_loss: 0.6927
# Epoch 16/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.5188 - auc: 0.5150 - loss: 0.6926 - val_accuracy: 0.5291 - val_auc: 0.4990 - val_loss: 0.6926
# Epoch 17/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.5223 - auc: 0.5138 - loss: 0.6924 - val_accuracy: 0.5281 - val_auc: 0.5000 - val_loss: 0.6927
# Epoch 18/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.5207 - auc: 0.5160 - loss: 0.6924 - val_accuracy: 0.5275 - val_auc: 0.4994 - val_loss: 0.6926
# Epoch 19/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.5205 - auc: 0.5078 - loss: 0.6926 - val_accuracy: 0.5281 - val_auc: 0.4997 - val_loss: 0.6927
# Epoch 20/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.5120 - auc: 0.5143 - loss: 0.6929 - val_accuracy: 0.5278 - val_auc: 0.4987 - val_loss: 0.6925
# Epoch 21/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - accuracy: 0.5221 - auc: 0.5133 - loss: 0.6921 - val_accuracy: 0.5289 - val_auc: 0.4959 - val_loss: 0.6927
# Epoch 22/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.5182 - auc: 0.5102 - loss: 0.6924 - val_accuracy: 0.5283 - val_auc: 0.4978 - val_loss: 0.6927
# Epoch 23/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.5229 - auc: 0.5171 - loss: 0.6923 - val_accuracy: 0.5284 - val_auc: 0.4970 - val_loss: 0.6926
# Epoch 24/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.5193 - auc: 0.5126 - loss: 0.6925 - val_accuracy: 0.5271 - val_auc: 0.4974 - val_loss: 0.6925
# Epoch 25/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.5204 - auc: 0.5135 - loss: 0.6921 - val_accuracy: 0.5275 - val_auc: 0.4992 - val_loss: 0.6924
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 221us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5123 - auc: 0.5032 - loss: 0.6951 - val_accuracy: 0.5193 - val_auc: 0.4908 - val_loss: 0.6932
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5156 - auc: 0.5094 - loss: 0.6931 - val_accuracy: 0.5217 - val_auc: 0.4942 - val_loss: 0.6927
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5153 - auc: 0.5073 - loss: 0.6929 - val_accuracy: 0.5240 - val_auc: 0.4959 - val_loss: 0.6925
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5093 - auc: 0.5094 - loss: 0.6931 - val_accuracy: 0.5312 - val_auc: 0.4998 - val_loss: 0.6916
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5185 - auc: 0.5142 - loss: 0.6921 - val_accuracy: 0.5259 - val_auc: 0.4995 - val_loss: 0.6923
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.5187 - auc: 0.5137 - loss: 0.6919 - val_accuracy: 0.5285 - val_auc: 0.4992 - val_loss: 0.6921
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.5187 - auc: 0.5143 - loss: 0.6921 - val_accuracy: 0.5308 - val_auc: 0.4991 - val_loss: 0.6918
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.5199 - auc: 0.5125 - loss: 0.6917 - val_accuracy: 0.5307 - val_auc: 0.4982 - val_loss: 0.6918
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.5220 - auc: 0.5128 - loss: 0.6917 - val_accuracy: 0.5245 - val_auc: 0.4987 - val_loss: 0.6927
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5149 - auc: 0.5057 - loss: 0.6968 - val_accuracy: 0.5133 - val_auc: 0.4994 - val_loss: 0.6944
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5031 - auc: 0.5073 - loss: 0.6945 - val_accuracy: 0.5296 - val_auc: 0.5048 - val_loss: 0.6920
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5152 - auc: 0.5110 - loss: 0.6935 - val_accuracy: 0.5276 - val_auc: 0.5016 - val_loss: 0.6922
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5180 - auc: 0.5142 - loss: 0.6926 - val_accuracy: 0.5279 - val_auc: 0.4994 - val_loss: 0.6924
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.5170 - auc: 0.5137 - loss: 0.6924 - val_accuracy: 0.5314 - val_auc: 0.5076 - val_loss: 0.6917
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.5188 - auc: 0.5103 - loss: 0.6928 - val_accuracy: 0.5282 - val_auc: 0.5012 - val_loss: 0.6923
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.5183 - auc: 0.5164 - loss: 0.6919 - val_accuracy: 0.5271 - val_auc: 0.4996 - val_loss: 0.6925
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.5160 - auc: 0.5110 - loss: 0.6925 - val_accuracy: 0.5274 - val_auc: 0.4985 - val_loss: 0.6924
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.5143 - auc: 0.5155 - loss: 0.6926 - val_accuracy: 0.5295 - val_auc: 0.4982 - val_loss: 0.6919
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 0.5199 - auc: 0.5157 - loss: 0.6920 - val_accuracy: 0.5304 - val_auc: 0.5004 - val_loss: 0.6918
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5102 - auc: 0.5052 - loss: 0.6982 - val_accuracy: 0.5305 - val_auc: 0.5051 - val_loss: 0.6943
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5205 - auc: 0.5153 - loss: 0.6947 - val_accuracy: 0.5321 - val_auc: 0.5048 - val_loss: 0.6937
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5184 - auc: 0.5142 - loss: 0.6938 - val_accuracy: 0.5284 - val_auc: 0.5077 - val_loss: 0.6934
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.5175 - auc: 0.5154 - loss: 0.6937 - val_accuracy: 0.5279 - val_auc: 0.4976 - val_loss: 0.6931
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.5161 - auc: 0.5113 - loss: 0.6934 - val_accuracy: 0.5251 - val_auc: 0.4986 - val_loss: 0.6933
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.5171 - auc: 0.5127 - loss: 0.6933 - val_accuracy: 0.5282 - val_auc: 0.4977 - val_loss: 0.6927
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.5204 - auc: 0.5129 - loss: 0.6928 - val_accuracy: 0.5281 - val_auc: 0.4970 - val_loss: 0.6927
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.5179 - auc: 0.5111 - loss: 0.6928 - val_accuracy: 0.5290 - val_auc: 0.5026 - val_loss: 0.6926
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 0.5240 - auc: 0.5151 - loss: 0.6920 - val_accuracy: 0.5282 - val_auc: 0.4992 - val_loss: 0.6927
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5170 - auc: 0.5136 - loss: 0.6927 - val_accuracy: 0.5273 - val_auc: 0.4976 - val_loss: 0.6924
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5218 - auc: 0.5175 - loss: 0.6922 - val_accuracy: 0.5290 - val_auc: 0.5019 - val_loss: 0.6922
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5251 - auc: 0.5143 - loss: 0.6919 - val_accuracy: 0.5278 - val_auc: 0.4993 - val_loss: 0.6925
# Epoch 13/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5177 - auc: 0.5163 - loss: 0.6923 - val_accuracy: 0.5293 - val_auc: 0.5018 - val_loss: 0.6921
# Epoch 14/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5213 - auc: 0.5153 - loss: 0.6920 - val_accuracy: 0.5258 - val_auc: 0.5015 - val_loss: 0.6927
# Epoch 15/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5193 - auc: 0.5147 - loss: 0.6920 - val_accuracy: 0.5271 - val_auc: 0.4981 - val_loss: 0.6923
# Epoch 16/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.5192 - auc: 0.5121 - loss: 0.6921 - val_accuracy: 0.5267 - val_auc: 0.4976 - val_loss: 0.6923
# Epoch 17/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.5217 - auc: 0.5165 - loss: 0.6920 - val_accuracy: 0.5279 - val_auc: 0.4984 - val_loss: 0.6921
# Epoch 18/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.5210 - auc: 0.5155 - loss: 0.6919 - val_accuracy: 0.5279 - val_auc: 0.4990 - val_loss: 0.6921
# Epoch 19/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.5198 - auc: 0.5124 - loss: 0.6919 - val_accuracy: 0.5272 - val_auc: 0.4957 - val_loss: 0.6924
# Epoch 20/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.5180 - auc: 0.5177 - loss: 0.6919 - val_accuracy: 0.5276 - val_auc: 0.4991 - val_loss: 0.6921
# Epoch 21/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5197 - auc: 0.5146 - loss: 0.6917 - val_accuracy: 0.5283 - val_auc: 0.5003 - val_loss: 0.6922
# Epoch 22/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.5153 - auc: 0.5131 - loss: 0.6922 - val_accuracy: 0.5280 - val_auc: 0.4990 - val_loss: 0.6919
# Epoch 23/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5221 - auc: 0.5121 - loss: 0.6917 - val_accuracy: 0.5285 - val_auc: 0.4953 - val_loss: 0.6921
# Epoch 24/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5199 - auc: 0.5155 - loss: 0.6918 - val_accuracy: 0.5287 - val_auc: 0.4991 - val_loss: 0.6920
# Epoch 25/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5157 - auc: 0.5117 - loss: 0.6922 - val_accuracy: 0.5274 - val_auc: 0.4961 - val_loss: 0.6922
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5028 - auc: 0.5115 - loss: 0.6959 - val_accuracy: 0.5255 - val_auc: 0.4945 - val_loss: 0.6927
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5178 - auc: 0.5126 - loss: 0.6928 - val_accuracy: 0.5251 - val_auc: 0.4927 - val_loss: 0.6925
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - auc: 0.5101 - loss: 0.6934 - val_accuracy: 0.5229 - val_auc: 0.4943 - val_loss: 0.6926
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.5186 - auc: 0.5155 - loss: 0.6931 - val_accuracy: 0.5255 - val_auc: 0.4943 - val_loss: 0.6920
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.5131 - auc: 0.5042 - loss: 0.6933 - val_accuracy: 0.5253 - val_auc: 0.4953 - val_loss: 0.6923
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.5217 - auc: 0.5147 - loss: 0.6926 - val_accuracy: 0.5249 - val_auc: 0.5002 - val_loss: 0.6924
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - accuracy: 0.5170 - auc: 0.5133 - loss: 0.6931 - val_accuracy: 0.5260 - val_auc: 0.4963 - val_loss: 0.6920
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.5174 - auc: 0.5179 - loss: 0.6921 - val_accuracy: 0.5283 - val_auc: 0.4992 - val_loss: 0.6921
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.5224 - auc: 0.5147 - loss: 0.6922 - val_accuracy: 0.5262 - val_auc: 0.4967 - val_loss: 0.6923
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.5140 - auc: 0.5107 - loss: 0.6929 - val_accuracy: 0.5260 - val_auc: 0.4970 - val_loss: 0.6922
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - accuracy: 0.5187 - auc: 0.5132 - loss: 0.6925 - val_accuracy: 0.5272 - val_auc: 0.4965 - val_loss: 0.6922
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5189 - auc: 0.5175 - loss: 0.6921 - val_accuracy: 0.5266 - val_auc: 0.4995 - val_loss: 0.6922
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4979 - auc: 0.4893 - loss: 0.7062 - val_accuracy: 0.5066 - val_auc: 0.4950 - val_loss: 0.6934
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5059 - auc: 0.5025 - loss: 0.6949 - val_accuracy: 0.5105 - val_auc: 0.4964 - val_loss: 0.6930
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5153 - auc: 0.5114 - loss: 0.6937 - val_accuracy: 0.5201 - val_auc: 0.4967 - val_loss: 0.6928
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5106 - auc: 0.5085 - loss: 0.6932 - val_accuracy: 0.5212 - val_auc: 0.4950 - val_loss: 0.6931
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5169 - auc: 0.5099 - loss: 0.6934 - val_accuracy: 0.5263 - val_auc: 0.4981 - val_loss: 0.6925
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.5182 - auc: 0.5079 - loss: 0.6931 - val_accuracy: 0.5266 - val_auc: 0.4980 - val_loss: 0.6926
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.5197 - auc: 0.5168 - loss: 0.6926 - val_accuracy: 0.5326 - val_auc: 0.5003 - val_loss: 0.6919
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.5199 - auc: 0.5177 - loss: 0.6923 - val_accuracy: 0.5295 - val_auc: 0.4992 - val_loss: 0.6923
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.5132 - auc: 0.5089 - loss: 0.6937 - val_accuracy: 0.5300 - val_auc: 0.4994 - val_loss: 0.6922
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.5102 - auc: 0.5071 - loss: 0.6936 - val_accuracy: 0.5296 - val_auc: 0.5003 - val_loss: 0.6922
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.5178 - auc: 0.5116 - loss: 0.6933 - val_accuracy: 0.5301 - val_auc: 0.5008 - val_loss: 0.6923
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - accuracy: 0.5208 - auc: 0.5169 - loss: 0.6922 - val_accuracy: 0.5301 - val_auc: 0.4988 - val_loss: 0.6922
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 231us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4977 - auc: 0.4931 - loss: 0.7047 - val_accuracy: 0.5002 - val_auc: 0.4992 - val_loss: 0.6971
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5071 - auc: 0.5004 - loss: 0.6974 - val_accuracy: 0.5222 - val_auc: 0.4983 - val_loss: 0.6957
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5159 - auc: 0.5117 - loss: 0.6963 - val_accuracy: 0.5287 - val_auc: 0.5042 - val_loss: 0.6946
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5190 - auc: 0.5106 - loss: 0.6953 - val_accuracy: 0.5239 - val_auc: 0.5038 - val_loss: 0.6946
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5200 - auc: 0.5094 - loss: 0.6949 - val_accuracy: 0.5246 - val_auc: 0.4988 - val_loss: 0.6945
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5159 - auc: 0.5107 - loss: 0.6948 - val_accuracy: 0.5256 - val_auc: 0.5013 - val_loss: 0.6940
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5182 - auc: 0.5124 - loss: 0.6944 - val_accuracy: 0.5285 - val_auc: 0.5016 - val_loss: 0.6936
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5190 - auc: 0.5142 - loss: 0.6941 - val_accuracy: 0.5294 - val_auc: 0.4981 - val_loss: 0.6934
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.5180 - auc: 0.5118 - loss: 0.6938 - val_accuracy: 0.5300 - val_auc: 0.5003 - val_loss: 0.6934
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.5190 - auc: 0.5167 - loss: 0.6940 - val_accuracy: 0.5297 - val_auc: 0.5007 - val_loss: 0.6932
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.5185 - auc: 0.5116 - loss: 0.6936 - val_accuracy: 0.5307 - val_auc: 0.5007 - val_loss: 0.6930
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.5201 - auc: 0.5130 - loss: 0.6931 - val_accuracy: 0.5286 - val_auc: 0.5021 - val_loss: 0.6931
# Epoch 13/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.5202 - auc: 0.5132 - loss: 0.6934 - val_accuracy: 0.5286 - val_auc: 0.5003 - val_loss: 0.6932
# Epoch 14/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.5149 - auc: 0.5127 - loss: 0.6934 - val_accuracy: 0.5291 - val_auc: 0.4980 - val_loss: 0.6929
# Epoch 15/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.5227 - auc: 0.5215 - loss: 0.6928 - val_accuracy: 0.5303 - val_auc: 0.4985 - val_loss: 0.6927
# Epoch 16/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5230 - auc: 0.5159 - loss: 0.6927 - val_accuracy: 0.5285 - val_auc: 0.4994 - val_loss: 0.6927
# Epoch 17/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5225 - auc: 0.5168 - loss: 0.6926 - val_accuracy: 0.5284 - val_auc: 0.4985 - val_loss: 0.6927
# Epoch 18/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5225 - auc: 0.5184 - loss: 0.6925 - val_accuracy: 0.5282 - val_auc: 0.4979 - val_loss: 0.6927
# Epoch 19/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5237 - auc: 0.5165 - loss: 0.6920 - val_accuracy: 0.5282 - val_auc: 0.5029 - val_loss: 0.6927
# Epoch 20/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5162 - auc: 0.5104 - loss: 0.6930 - val_accuracy: 0.5283 - val_auc: 0.4997 - val_loss: 0.6925
# Epoch 21/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5208 - auc: 0.5142 - loss: 0.6926 - val_accuracy: 0.5278 - val_auc: 0.4963 - val_loss: 0.6927
# Epoch 22/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5221 - auc: 0.5148 - loss: 0.6924 - val_accuracy: 0.5262 - val_auc: 0.4951 - val_loss: 0.6928
# Epoch 23/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5204 - auc: 0.5155 - loss: 0.6925 - val_accuracy: 0.5272 - val_auc: 0.5011 - val_loss: 0.6924
# Epoch 24/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5168 - auc: 0.5109 - loss: 0.6928 - val_accuracy: 0.5276 - val_auc: 0.4975 - val_loss: 0.6924
# Epoch 25/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5196 - auc: 0.5147 - loss: 0.6924 - val_accuracy: 0.5272 - val_auc: 0.4978 - val_loss: 0.6924
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4974 - auc: 0.4997 - loss: 0.6981 - val_accuracy: 0.5163 - val_auc: 0.4973 - val_loss: 0.6927
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.5101 - auc: 0.5079 - loss: 0.6946 - val_accuracy: 0.5294 - val_auc: 0.4984 - val_loss: 0.6919
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 0.5122 - auc: 0.5092 - loss: 0.6938 - val_accuracy: 0.5235 - val_auc: 0.4988 - val_loss: 0.6922
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.5191 - auc: 0.5185 - loss: 0.6927 - val_accuracy: 0.5269 - val_auc: 0.5006 - val_loss: 0.6918
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.5158 - auc: 0.5057 - loss: 0.6925 - val_accuracy: 0.5250 - val_auc: 0.5016 - val_loss: 0.6922
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5146 - auc: 0.5073 - loss: 0.6930 - val_accuracy: 0.5278 - val_auc: 0.4992 - val_loss: 0.6921
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5152 - auc: 0.5039 - loss: 0.6930 - val_accuracy: 0.5233 - val_auc: 0.4982 - val_loss: 0.6924
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5185 - auc: 0.5124 - loss: 0.6920 - val_accuracy: 0.5268 - val_auc: 0.5003 - val_loss: 0.6921
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5197 - auc: 0.5116 - loss: 0.6923 - val_accuracy: 0.5261 - val_auc: 0.4996 - val_loss: 0.6921
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5062 - auc: 0.5029 - loss: 0.6980 - val_accuracy: 0.5237 - val_auc: 0.4919 - val_loss: 0.6929
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - accuracy: 0.5116 - auc: 0.5080 - loss: 0.6950 - val_accuracy: 0.5255 - val_auc: 0.4964 - val_loss: 0.6929
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.5166 - auc: 0.5011 - loss: 0.6946 - val_accuracy: 0.5266 - val_auc: 0.4955 - val_loss: 0.6926
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.5147 - auc: 0.5062 - loss: 0.6940 - val_accuracy: 0.5271 - val_auc: 0.4948 - val_loss: 0.6927
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.5156 - auc: 0.5169 - loss: 0.6928 - val_accuracy: 0.5270 - val_auc: 0.4974 - val_loss: 0.6927
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.5170 - auc: 0.5144 - loss: 0.6931 - val_accuracy: 0.5279 - val_auc: 0.4957 - val_loss: 0.6925
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5191 - auc: 0.5119 - loss: 0.6926 - val_accuracy: 0.5278 - val_auc: 0.4948 - val_loss: 0.6925
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.5198 - auc: 0.5128 - loss: 0.6928 - val_accuracy: 0.5280 - val_auc: 0.4965 - val_loss: 0.6925
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5198 - auc: 0.5131 - loss: 0.6926 - val_accuracy: 0.5300 - val_auc: 0.4966 - val_loss: 0.6922
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5134 - auc: 0.5128 - loss: 0.6927 - val_accuracy: 0.5279 - val_auc: 0.4970 - val_loss: 0.6924
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5195 - auc: 0.5151 - loss: 0.6921 - val_accuracy: 0.5294 - val_auc: 0.4995 - val_loss: 0.6921
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5200 - auc: 0.5157 - loss: 0.6919 - val_accuracy: 0.5271 - val_auc: 0.4974 - val_loss: 0.6926
# Epoch 13/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5190 - auc: 0.5184 - loss: 0.6922 - val_accuracy: 0.5260 - val_auc: 0.4984 - val_loss: 0.6924
# Epoch 14/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5191 - auc: 0.5131 - loss: 0.6924 - val_accuracy: 0.5273 - val_auc: 0.4959 - val_loss: 0.6924
# Epoch 15/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5152 - auc: 0.5122 - loss: 0.6924 - val_accuracy: 0.5285 - val_auc: 0.4981 - val_loss: 0.6920
# Epoch 16/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5170 - auc: 0.5120 - loss: 0.6924 - val_accuracy: 0.5278 - val_auc: 0.4980 - val_loss: 0.6922
# Epoch 17/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.5179 - auc: 0.5155 - loss: 0.6920 - val_accuracy: 0.5281 - val_auc: 0.4948 - val_loss: 0.6921
# Epoch 18/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5195 - auc: 0.5141 - loss: 0.6919 - val_accuracy: 0.5269 - val_auc: 0.4957 - val_loss: 0.6925
# Epoch 19/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5144 - auc: 0.5156 - loss: 0.6924 - val_accuracy: 0.5272 - val_auc: 0.4977 - val_loss: 0.6923
# Epoch 20/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5185 - auc: 0.5139 - loss: 0.6920 - val_accuracy: 0.5285 - val_auc: 0.4956 - val_loss: 0.6921
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5024 - auc: 0.5090 - loss: 0.7033 - val_accuracy: 0.5273 - val_auc: 0.4972 - val_loss: 0.6943
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - accuracy: 0.5166 - auc: 0.5132 - loss: 0.6971 - val_accuracy: 0.5266 - val_auc: 0.5018 - val_loss: 0.6944
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.5189 - auc: 0.5128 - loss: 0.6957 - val_accuracy: 0.5295 - val_auc: 0.4996 - val_loss: 0.6936
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.5219 - auc: 0.5141 - loss: 0.6945 - val_accuracy: 0.5283 - val_auc: 0.4986 - val_loss: 0.6932
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.5181 - auc: 0.5114 - loss: 0.6935 - val_accuracy: 0.5279 - val_auc: 0.4980 - val_loss: 0.6930
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.5156 - auc: 0.5151 - loss: 0.6939 - val_accuracy: 0.5279 - val_auc: 0.4970 - val_loss: 0.6929
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - accuracy: 0.5194 - auc: 0.5152 - loss: 0.6933 - val_accuracy: 0.5296 - val_auc: 0.5008 - val_loss: 0.6926
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.5215 - auc: 0.5154 - loss: 0.6927 - val_accuracy: 0.5285 - val_auc: 0.4969 - val_loss: 0.6927
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.5210 - auc: 0.5180 - loss: 0.6924 - val_accuracy: 0.5301 - val_auc: 0.5007 - val_loss: 0.6923
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.5169 - auc: 0.5145 - loss: 0.6926 - val_accuracy: 0.5292 - val_auc: 0.4988 - val_loss: 0.6923
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.5194 - auc: 0.5134 - loss: 0.6926 - val_accuracy: 0.5300 - val_auc: 0.5000 - val_loss: 0.6922
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.5195 - auc: 0.5142 - loss: 0.6925 - val_accuracy: 0.5272 - val_auc: 0.4981 - val_loss: 0.6924
# Epoch 13/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.5225 - auc: 0.5119 - loss: 0.6921 - val_accuracy: 0.5273 - val_auc: 0.4976 - val_loss: 0.6924
# Epoch 14/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5205 - auc: 0.5116 - loss: 0.6925 - val_accuracy: 0.5275 - val_auc: 0.4970 - val_loss: 0.6924
# Epoch 15/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5142 - auc: 0.5071 - loss: 0.6928 - val_accuracy: 0.5274 - val_auc: 0.4969 - val_loss: 0.6924
# Epoch 16/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5232 - auc: 0.5172 - loss: 0.6919 - val_accuracy: 0.5271 - val_auc: 0.4955 - val_loss: 0.6927
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5135 - auc: 0.5097 - loss: 0.6996 - val_accuracy: 0.5223 - val_auc: 0.4999 - val_loss: 0.6925
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5086 - auc: 0.5062 - loss: 0.6974 - val_accuracy: 0.5255 - val_auc: 0.4987 - val_loss: 0.6922
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5145 - auc: 0.5173 - loss: 0.6947 - val_accuracy: 0.5264 - val_auc: 0.5037 - val_loss: 0.6920
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.5117 - auc: 0.5112 - loss: 0.6955 - val_accuracy: 0.5280 - val_auc: 0.5020 - val_loss: 0.6921
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5122 - auc: 0.5095 - loss: 0.6959 - val_accuracy: 0.5303 - val_auc: 0.5011 - val_loss: 0.6919
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5127 - auc: 0.5144 - loss: 0.6939 - val_accuracy: 0.5246 - val_auc: 0.4990 - val_loss: 0.6923
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5134 - auc: 0.5117 - loss: 0.6934 - val_accuracy: 0.5280 - val_auc: 0.5033 - val_loss: 0.6919
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5141 - auc: 0.5128 - loss: 0.6936 - val_accuracy: 0.5264 - val_auc: 0.4997 - val_loss: 0.6921
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5121 - auc: 0.5058 - loss: 0.6938 - val_accuracy: 0.5272 - val_auc: 0.5021 - val_loss: 0.6920
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5163 - auc: 0.5133 - loss: 0.6937 - val_accuracy: 0.5275 - val_auc: 0.5006 - val_loss: 0.6920
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5187 - auc: 0.5139 - loss: 0.6929 - val_accuracy: 0.5280 - val_auc: 0.5005 - val_loss: 0.6921
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.5224 - auc: 0.5182 - loss: 0.6928 - val_accuracy: 0.5272 - val_auc: 0.5027 - val_loss: 0.6921
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 223us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5028 - auc: 0.4926 - loss: 0.7117 - val_accuracy: 0.5047 - val_auc: 0.4982 - val_loss: 0.6937
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - accuracy: 0.5017 - auc: 0.4991 - loss: 0.6963 - val_accuracy: 0.5100 - val_auc: 0.4975 - val_loss: 0.6933
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.5114 - auc: 0.5041 - loss: 0.6960 - val_accuracy: 0.5098 - val_auc: 0.4991 - val_loss: 0.6932
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.5125 - auc: 0.5105 - loss: 0.6939 - val_accuracy: 0.5242 - val_auc: 0.4982 - val_loss: 0.6926
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.5128 - auc: 0.5078 - loss: 0.6943 - val_accuracy: 0.5256 - val_auc: 0.4996 - val_loss: 0.6925
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5193 - auc: 0.5142 - loss: 0.6931 - val_accuracy: 0.5307 - val_auc: 0.5011 - val_loss: 0.6921
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5195 - auc: 0.5084 - loss: 0.6936 - val_accuracy: 0.5262 - val_auc: 0.4994 - val_loss: 0.6926
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5145 - auc: 0.5065 - loss: 0.6937 - val_accuracy: 0.5295 - val_auc: 0.5010 - val_loss: 0.6923
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5130 - auc: 0.5094 - loss: 0.6933 - val_accuracy: 0.5294 - val_auc: 0.4993 - val_loss: 0.6923
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5183 - auc: 0.5168 - loss: 0.6929 - val_accuracy: 0.5274 - val_auc: 0.5005 - val_loss: 0.6925
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5187 - auc: 0.5128 - loss: 0.6927 - val_accuracy: 0.5283 - val_auc: 0.4982 - val_loss: 0.6925
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5079 - auc: 0.5138 - loss: 0.7025 - val_accuracy: 0.5268 - val_auc: 0.5003 - val_loss: 0.6955
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5165 - auc: 0.5050 - loss: 0.6964 - val_accuracy: 0.5264 - val_auc: 0.5004 - val_loss: 0.6951
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5182 - auc: 0.5134 - loss: 0.6951 - val_accuracy: 0.5266 - val_auc: 0.4986 - val_loss: 0.6946
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5188 - auc: 0.5115 - loss: 0.6954 - val_accuracy: 0.5261 - val_auc: 0.4995 - val_loss: 0.6942
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5183 - auc: 0.5201 - loss: 0.6937 - val_accuracy: 0.5257 - val_auc: 0.4990 - val_loss: 0.6940
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5183 - auc: 0.5092 - loss: 0.6943 - val_accuracy: 0.5267 - val_auc: 0.5006 - val_loss: 0.6938
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5155 - auc: 0.5159 - loss: 0.6936 - val_accuracy: 0.5293 - val_auc: 0.4980 - val_loss: 0.6933
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5144 - auc: 0.5087 - loss: 0.6938 - val_accuracy: 0.5278 - val_auc: 0.4987 - val_loss: 0.6933
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5192 - auc: 0.5111 - loss: 0.6935 - val_accuracy: 0.5272 - val_auc: 0.4988 - val_loss: 0.6934
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.5198 - auc: 0.5117 - loss: 0.6933 - val_accuracy: 0.5261 - val_auc: 0.4977 - val_loss: 0.6932
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.5190 - auc: 0.5148 - loss: 0.6934 - val_accuracy: 0.5273 - val_auc: 0.4988 - val_loss: 0.6930
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.5190 - auc: 0.5139 - loss: 0.6932 - val_accuracy: 0.5276 - val_auc: 0.4991 - val_loss: 0.6930
# Epoch 13/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.5192 - auc: 0.5097 - loss: 0.6930 - val_accuracy: 0.5262 - val_auc: 0.5009 - val_loss: 0.6928
# Epoch 14/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.5155 - auc: 0.5139 - loss: 0.6928 - val_accuracy: 0.5272 - val_auc: 0.4997 - val_loss: 0.6927
# Epoch 15/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.5189 - auc: 0.5160 - loss: 0.6928 - val_accuracy: 0.5270 - val_auc: 0.4992 - val_loss: 0.6928
# Epoch 16/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.5196 - auc: 0.5119 - loss: 0.6926 - val_accuracy: 0.5272 - val_auc: 0.4986 - val_loss: 0.6926
# Epoch 17/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.5209 - auc: 0.5145 - loss: 0.6925 - val_accuracy: 0.5279 - val_auc: 0.5023 - val_loss: 0.6924
# Epoch 18/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.5226 - auc: 0.5158 - loss: 0.6920 - val_accuracy: 0.5283 - val_auc: 0.4990 - val_loss: 0.6924
# Epoch 19/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.5182 - auc: 0.5148 - loss: 0.6924 - val_accuracy: 0.5280 - val_auc: 0.4984 - val_loss: 0.6924
# Epoch 20/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.5192 - auc: 0.5153 - loss: 0.6922 - val_accuracy: 0.5271 - val_auc: 0.5011 - val_loss: 0.6923
# Epoch 21/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.5233 - auc: 0.5120 - loss: 0.6922 - val_accuracy: 0.5278 - val_auc: 0.5002 - val_loss: 0.6924
# Epoch 22/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.5243 - auc: 0.5176 - loss: 0.6921 - val_accuracy: 0.5280 - val_auc: 0.5015 - val_loss: 0.6923
# Epoch 23/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5210 - auc: 0.5226 - loss: 0.6920 - val_accuracy: 0.5276 - val_auc: 0.5006 - val_loss: 0.6922
# Epoch 24/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5176 - auc: 0.5134 - loss: 0.6924 - val_accuracy: 0.5282 - val_auc: 0.5023 - val_loss: 0.6923
# Epoch 25/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5166 - auc: 0.5143 - loss: 0.6922 - val_accuracy: 0.5274 - val_auc: 0.4961 - val_loss: 0.6922
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# Epoch 1/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5140 - auc: 0.5146 - loss: 0.6926 - val_accuracy: 0.5247 - val_auc: 0.5037 - val_loss: 0.6928
# Epoch 2/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5213 - auc: 0.5170 - loss: 0.6918 - val_accuracy: 0.5259 - val_auc: 0.5003 - val_loss: 0.6922
# Epoch 3/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5189 - auc: 0.5163 - loss: 0.6919 - val_accuracy: 0.5267 - val_auc: 0.5020 - val_loss: 0.6922
# Epoch 4/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5210 - auc: 0.5120 - loss: 0.6920 - val_accuracy: 0.5321 - val_auc: 0.4996 - val_loss: 0.6917
# Epoch 5/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5229 - auc: 0.5171 - loss: 0.6916 - val_accuracy: 0.5263 - val_auc: 0.4992 - val_loss: 0.6927
# Epoch 6/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5203 - auc: 0.5145 - loss: 0.6917 - val_accuracy: 0.5296 - val_auc: 0.5046 - val_loss: 0.6919
# Epoch 7/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5203 - auc: 0.5123 - loss: 0.6919 - val_accuracy: 0.5256 - val_auc: 0.5017 - val_loss: 0.6924
# Epoch 8/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5137 - auc: 0.5136 - loss: 0.6919 - val_accuracy: 0.5274 - val_auc: 0.5016 - val_loss: 0.6920
# Epoch 9/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5202 - auc: 0.5136 - loss: 0.6916 - val_accuracy: 0.5332 - val_auc: 0.5083 - val_loss: 0.6913
# Epoch 10/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.5156 - auc: 0.5143 - loss: 0.6921 - val_accuracy: 0.5325 - val_auc: 0.5019 - val_loss: 0.6918
# Epoch 11/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.5206 - auc: 0.5197 - loss: 0.6917 - val_accuracy: 0.5319 - val_auc: 0.5062 - val_loss: 0.6916
# Epoch 12/25
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - accuracy: 0.5240 - auc: 0.5181 - loss: 0.6913 - val_accuracy: 0.5313 - val_auc: 0.5065 - val_loss: 0.6917
# Epoch 13/25
# ...
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7544 - auc: 0.8409 - loss: 0.6732 - val_accuracy: 0.4619 - val_auc: 0.3879 - val_loss: 0.9917
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5693 - auc: 0.5491 - loss: 0.6905 - val_accuracy: 0.4905 - val_auc: 0.4263 - val_loss: 0.7419
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6799 - auc: 0.7315 - loss: 0.5931 - val_accuracy: 0.4643 - val_auc: 0.4089 - val_loss: 0.7930
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7156 - auc: 0.7776 - loss: 0.5536 - val_accuracy: 0.4750 - val_auc: 0.3962 - val_loss: 0.8556
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7303 - auc: 0.8073 - loss: 0.5215 - val_accuracy: 0.4583 - val_auc: 0.3948 - val_loss: 0.8527
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7725 - auc: 0.8448 - loss: 0.4867 - val_accuracy: 0.4738 - val_auc: 0.4042 - val_loss: 0.8730
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7706 - auc: 0.8554 - loss: 0.4703 - val_accuracy: 0.4679 - val_auc: 0.3936 - val_loss: 0.9517
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5557 - auc: 0.5227 - loss: 0.7027 - val_accuracy: 0.5440 - val_auc: 0.4679 - val_loss: 0.7196
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6657 - auc: 0.7137 - loss: 0.6275 - val_accuracy: 0.5060 - val_auc: 0.3817 - val_loss: 0.7876
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6950 - auc: 0.7631 - loss: 0.5810 - val_accuracy: 0.4798 - val_auc: 0.3629 - val_loss: 0.8513
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7198 - auc: 0.7995 - loss: 0.5475 - val_accuracy: 0.4464 - val_auc: 0.3660 - val_loss: 0.8855
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7445 - auc: 0.8254 - loss: 0.5171 - val_accuracy: 0.4631 - val_auc: 0.3833 - val_loss: 0.9089
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7737 - auc: 0.8489 - loss: 0.4834 - val_accuracy: 0.4452 - val_auc: 0.3757 - val_loss: 0.9439
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5395 - auc: 0.5228 - loss: 0.8604 - val_accuracy: 0.5119 - val_auc: 0.4170 - val_loss: 0.8958
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6717 - auc: 0.7355 - loss: 0.7642 - val_accuracy: 0.4690 - val_auc: 0.3735 - val_loss: 0.9540
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7170 - auc: 0.7708 - loss: 0.7278 - val_accuracy: 0.4905 - val_auc: 0.3935 - val_loss: 0.9699
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7358 - auc: 0.7968 - loss: 0.6961 - val_accuracy: 0.4714 - val_auc: 0.3968 - val_loss: 1.0099
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7597 - auc: 0.8337 - loss: 0.6539 - val_accuracy: 0.4488 - val_auc: 0.3907 - val_loss: 1.0634
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7793 - auc: 0.8538 - loss: 0.6235 - val_accuracy: 0.4726 - val_auc: 0.4021 - val_loss: 1.0715
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6275 - auc: 0.5651 - loss: 0.6707 - val_accuracy: 0.5214 - val_auc: 0.4636 - val_loss: 0.7053
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6651 - auc: 0.6748 - loss: 0.6327 - val_accuracy: 0.5262 - val_auc: 0.4338 - val_loss: 0.7334
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6842 - auc: 0.7420 - loss: 0.5941 - val_accuracy: 0.5286 - val_auc: 0.4306 - val_loss: 0.7634
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7015 - auc: 0.7748 - loss: 0.5642 - val_accuracy: 0.5119 - val_auc: 0.4255 - val_loss: 0.7886
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7229 - auc: 0.7719 - loss: 0.5594 - val_accuracy: 0.4929 - val_auc: 0.4095 - val_loss: 0.8089
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7407 - auc: 0.7909 - loss: 0.5359 - val_accuracy: 0.4679 - val_auc: 0.4093 - val_loss: 0.8184
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6054 - auc: 0.5523 - loss: 0.6847 - val_accuracy: 0.5298 - val_auc: 0.3820 - val_loss: 0.7351
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6573 - auc: 0.6793 - loss: 0.6418 - val_accuracy: 0.5071 - val_auc: 0.3659 - val_loss: 0.7656
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6698 - auc: 0.7057 - loss: 0.6225 - val_accuracy: 0.4762 - val_auc: 0.3522 - val_loss: 0.8066
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7044 - auc: 0.7670 - loss: 0.5842 - val_accuracy: 0.4464 - val_auc: 0.3571 - val_loss: 0.8408
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7109 - auc: 0.7748 - loss: 0.5756 - val_accuracy: 0.4571 - val_auc: 0.3639 - val_loss: 0.8600
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7375 - auc: 0.8059 - loss: 0.5474 - val_accuracy: 0.4226 - val_auc: 0.3628 - val_loss: 0.9046
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5878 - auc: 0.5648 - loss: 0.8492 - val_accuracy: 0.5452 - val_auc: 0.5555 - val_loss: 0.8525
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6615 - auc: 0.6667 - loss: 0.8016 - val_accuracy: 0.5262 - val_auc: 0.5143 - val_loss: 0.8765
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6950 - auc: 0.7280 - loss: 0.7635 - val_accuracy: 0.5369 - val_auc: 0.4649 - val_loss: 0.9060
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7005 - auc: 0.7667 - loss: 0.7375 - val_accuracy: 0.5298 - val_auc: 0.4542 - val_loss: 0.9363
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7104 - auc: 0.7889 - loss: 0.7225 - val_accuracy: 0.5024 - val_auc: 0.4343 - val_loss: 0.9611
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7343 - auc: 0.8001 - loss: 0.6973 - val_accuracy: 0.4857 - val_auc: 0.4351 - val_loss: 0.9709
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5599 - auc: 0.5388 - loss: 0.6892 - val_accuracy: 0.5488 - val_auc: 0.4460 - val_loss: 0.6964
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6518 - auc: 0.6744 - loss: 0.6257 - val_accuracy: 0.4869 - val_auc: 0.4102 - val_loss: 0.7316
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6709 - auc: 0.7067 - loss: 0.6030 - val_accuracy: 0.4893 - val_auc: 0.4001 - val_loss: 0.7678
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6902 - auc: 0.7496 - loss: 0.5717 - val_accuracy: 0.4833 - val_auc: 0.3941 - val_loss: 0.7859
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7132 - auc: 0.7755 - loss: 0.5522 - val_accuracy: 0.4810 - val_auc: 0.3887 - val_loss: 0.8307
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7370 - auc: 0.7947 - loss: 0.5295 - val_accuracy: 0.4774 - val_auc: 0.3930 - val_loss: 0.8620
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5966 - auc: 0.5535 - loss: 0.6935 - val_accuracy: 0.4940 - val_auc: 0.3830 - val_loss: 0.7561
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6759 - auc: 0.6702 - loss: 0.6382 - val_accuracy: 0.4405 - val_auc: 0.3657 - val_loss: 0.8289
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6806 - auc: 0.7166 - loss: 0.6110 - val_accuracy: 0.4560 - val_auc: 0.3579 - val_loss: 0.8842
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7002 - auc: 0.7524 - loss: 0.5862 - val_accuracy: 0.4607 - val_auc: 0.3696 - val_loss: 0.9169
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7202 - auc: 0.7770 - loss: 0.5663 - val_accuracy: 0.4548 - val_auc: 0.3747 - val_loss: 0.9752
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7355 - auc: 0.7985 - loss: 0.5459 - val_accuracy: 0.4595 - val_auc: 0.3679 - val_loss: 0.9758
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5601 - auc: 0.5220 - loss: 0.8709 - val_accuracy: 0.5619 - val_auc: 0.4077 - val_loss: 0.8686
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6551 - auc: 0.6603 - loss: 0.8002 - val_accuracy: 0.5000 - val_auc: 0.3750 - val_loss: 0.9023
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6636 - auc: 0.6919 - loss: 0.7780 - val_accuracy: 0.4750 - val_auc: 0.3722 - val_loss: 0.9380
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6726 - auc: 0.7398 - loss: 0.7421 - val_accuracy: 0.4571 - val_auc: 0.3706 - val_loss: 0.9848
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7143 - auc: 0.7665 - loss: 0.7151 - val_accuracy: 0.4607 - val_auc: 0.3755 - val_loss: 1.0029
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7413 - auc: 0.8020 - loss: 0.6811 - val_accuracy: 0.4536 - val_auc: 0.3771 - val_loss: 1.0392
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5721 - auc: 0.5901 - loss: 0.6854 - val_accuracy: 0.5226 - val_auc: 0.4619 - val_loss: 0.6931
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6273 - auc: 0.6231 - loss: 0.6527 - val_accuracy: 0.5262 - val_auc: 0.4317 - val_loss: 0.7082
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6831 - auc: 0.6690 - loss: 0.6242 - val_accuracy: 0.5107 - val_auc: 0.3699 - val_loss: 0.7367
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6759 - auc: 0.7007 - loss: 0.6081 - val_accuracy: 0.5167 - val_auc: 0.3787 - val_loss: 0.7535
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6923 - auc: 0.7352 - loss: 0.5892 - val_accuracy: 0.5226 - val_auc: 0.4135 - val_loss: 0.7640
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7128 - auc: 0.7541 - loss: 0.5665 - val_accuracy: 0.5167 - val_auc: 0.4122 - val_loss: 0.7771
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5634 - auc: 0.4937 - loss: 0.7058 - val_accuracy: 0.5738 - val_auc: 0.4277 - val_loss: 0.7096
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6054 - auc: 0.5811 - loss: 0.6827 - val_accuracy: 0.5679 - val_auc: 0.4042 - val_loss: 0.7225
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6345 - auc: 0.6391 - loss: 0.6562 - val_accuracy: 0.5583 - val_auc: 0.4017 - val_loss: 0.7403
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6631 - auc: 0.6891 - loss: 0.6319 - val_accuracy: 0.5131 - val_auc: 0.3915 - val_loss: 0.7613
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6610 - auc: 0.7174 - loss: 0.6272 - val_accuracy: 0.4976 - val_auc: 0.3757 - val_loss: 0.7762
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6890 - auc: 0.7432 - loss: 0.5990 - val_accuracy: 0.4738 - val_auc: 0.3737 - val_loss: 0.7914
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5817 - auc: 0.5131 - loss: 0.8809 - val_accuracy: 0.5190 - val_auc: 0.4839 - val_loss: 0.8670
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6358 - auc: 0.6280 - loss: 0.8248 - val_accuracy: 0.5167 - val_auc: 0.4441 - val_loss: 0.8918
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6590 - auc: 0.6633 - loss: 0.8059 - val_accuracy: 0.5012 - val_auc: 0.4147 - val_loss: 0.9170
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6813 - auc: 0.7042 - loss: 0.7780 - val_accuracy: 0.5000 - val_auc: 0.4105 - val_loss: 0.9340
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6869 - auc: 0.7361 - loss: 0.7554 - val_accuracy: 0.4976 - val_auc: 0.4073 - val_loss: 0.9531
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6881 - auc: 0.7560 - loss: 0.7413 - val_accuracy: 0.4940 - val_auc: 0.4064 - val_loss: 0.9676
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5920 - auc: 0.5647 - loss: 0.6677 - val_accuracy: 0.6216 - val_auc: 0.6815 - val_loss: 0.6559
# Epoch 2/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6584 - auc: 0.7168 - loss: 0.6159 - val_accuracy: 0.6419 - val_auc: 0.6816 - val_loss: 0.6432
# Epoch 3/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6996 - auc: 0.7717 - loss: 0.5812 - val_accuracy: 0.6347 - val_auc: 0.6709 - val_loss: 0.6474
# Epoch 4/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7198 - auc: 0.8013 - loss: 0.5574 - val_accuracy: 0.6563 - val_auc: 0.6550 - val_loss: 0.6521
# Epoch 5/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7432 - auc: 0.8295 - loss: 0.5333 - val_accuracy: 0.6503 - val_auc: 0.6497 - val_loss: 0.6528
# Epoch 6/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7506 - auc: 0.8383 - loss: 0.5171 - val_accuracy: 0.6443 - val_auc: 0.6439 - val_loss: 0.6538
# Epoch 7/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7600 - auc: 0.8529 - loss: 0.5009 - val_accuracy: 0.6204 - val_auc: 0.6363 - val_loss: 0.6576
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test AUC: 0.6828291296956147
# Test accuracy: 0.6419161676646706
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.30      0.43       367
#          1.0       0.62      0.91      0.74       468
#
#     accuracy                           0.64       835
#    macro avg       0.67      0.61      0.58       835
# weighted avg       0.67      0.64      0.60       835
# [{'Horizon': 'y_1',
#   'Features': 'raw',
#   'Val AUC': 0.5092998901249828,
#   'Val Accuracy': 0.5317094579767391,
#   'Test AUC': 0.5095900867812929,
#   'Test Accuracy': 0.5350248207391064},
#  {'Horizon': 'y_20',
#   'Features': 'raw',
#   'Val AUC': 0.5195040186736671,
#   'Val Accuracy': 0.6039924166387867,
#   'Test AUC': 0.5025463902381284,
#   'Test Accuracy': 0.6097779771249159},
#  {'Horizon': 'y_60',
#   'Features': 'raw',
#   'Val AUC': 0.531987413655761,
#   'Val Accuracy': 0.6263115415657788,
#   'Test AUC': 0.5015413331985774,
#   'Test Accuracy': 0.6927179962894249},
#  {'Horizon': 'y_1',
#   'Features': 'eng',
#   'Val AUC': 0.5193705731676294,
#   'Val Accuracy': 0.5234636227372305,
#   'Test AUC': 0.5055099031787674,
#   'Test Accuracy': 0.5316558441558441},
#  {'Horizon': 'y_20',
#   'Features': 'eng',
#   'Val AUC': 0.5091201542824343,
#   'Val Accuracy': 0.5738916256157636,
#   'Test AUC': 0.5116656124103907,
#   'Test Accuracy': 0.5696590775038339},
#  {'Horizon': 'y_60',
#   'Features': 'eng',
#   'Val AUC': 0.5323812378993714,
#   'Val Accuracy': 0.6149173955296404,
#   'Test AUC': 0.5109843008862441,
#   'Test Accuracy': 0.6781131614322375},
#  {'Horizon': 'y_1',
#   'Features': 'fund',
#   'Val AUC': 0.5283255042052264,
#   'Val Accuracy': 0.5308108108108108,
#   'Test AUC': 0.5271935096153846,
#   'Test Accuracy': 0.5413043478260869},
#  {'Horizon': 'y_20',
#   'Features': 'fund',
#   'Val AUC': 0.5861991623148974,
#   'Val Accuracy': 0.5516483516483517,
#   'Test AUC': 0.5995604754182653,
#   'Test Accuracy': 0.5659340659340659},
#  {'Horizon': 'y_60',
#   'Features': 'fund',
#   'Val AUC': 0.6774054088674684,
#   'Val Accuracy': 0.5886363636363636,
#   'Test AUC': 0.7264763515820772,
#   'Test Accuracy': 0.5136363636363637},
#  {'Horizon': 'y_1',
#   'Features': 'fund_eng',
#   'Val AUC': 0.5421819223255291,
#   'Val Accuracy': 0.5209039548022599,
#   'Test AUC': 0.4974590950830621,
#   'Test Accuracy': 0.5011363636363636},
#  {'Horizon': 'y_20',
#   'Features': 'fund_eng',
#   'Val AUC': 0.5902751322751323,
#   'Val Accuracy': 0.5609195402298851,
#   'Test AUC': 0.5738575342465754,
#   'Test Accuracy': 0.5468208092485549},
#  {'Horizon': 'y_60',
#   'Features': 'fund_eng',
#   'Val AUC': 0.6052790416937506,
#   'Val Accuracy': 0.5392857142857143,
#   'Test AUC': 0.6828291296956147,
#   'Test Accuracy': 0.6419161676646706}]

# %%
res_df = pd.DataFrame(res)
val_acc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Val Accuracy")

val_acc_df = val_acc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

val_acc_df = val_acc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

val_acc_st = (
    val_acc_df.style
      .set_caption("Table 1: MLP - Summary Validation Accuracy")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)

dfi.export(val_acc_st, "MLP_table_validation_accuracy.png", table_conversion="matplotlib")

# %%
val_acc_st
# Out:
# <style type="text/css">
# #T_de041 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_de041 th {
#   padding: 10px;
# }
# #T_de041  td {
#   padding: 10px;
# }
# #T_de041 th {
#   font-size: 12pt;
# }
# #T_de041 td {
#   font-size: 11pt;
# }
# #T_de041_row0_col0, #T_de041_row0_col1, #T_de041_row0_col2, #T_de041_row1_col0, #T_de041_row1_col1, #T_de041_row1_col2, #T_de041_row2_col0, #T_de041_row2_col1, #T_de041_row2_col2, #T_de041_row3_col0, #T_de041_row3_col1, #T_de041_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_de041">
#   <caption>Table 1: MLP - Summary Validation Accuracy</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_de041_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_de041_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_de041_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de041_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_de041_row0_col0" class="data row0 col0" >0.5235</td>
#       <td id="T_de041_row0_col1" class="data row0 col1" >0.5739</td>
#       <td id="T_de041_row0_col2" class="data row0 col2" >0.6149</td>
#     </tr>
#     <tr>
#       <th id="T_de041_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_de041_row1_col0" class="data row1 col0" >0.5308</td>
#       <td id="T_de041_row1_col1" class="data row1 col1" >0.5516</td>
#       <td id="T_de041_row1_col2" class="data row1 col2" >0.5886</td>
#     </tr>
#     <tr>
#       <th id="T_de041_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_de041_row2_col0" class="data row2 col0" >0.5209</td>
#       <td id="T_de041_row2_col1" class="data row2 col1" >0.5609</td>
#       <td id="T_de041_row2_col2" class="data row2 col2" >0.5393</td>
#     </tr>
#     <tr>
#       <th id="T_de041_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_de041_row3_col0" class="data row3 col0" >0.5317</td>
#       <td id="T_de041_row3_col1" class="data row3 col1" >0.6040</td>
#       <td id="T_de041_row3_col2" class="data row3 col2" >0.6263</td>
#     </tr>
#   </tbody>
# </table>

# %%
res_df = pd.DataFrame(res)
val_auc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Val AUC")

val_auc_df = val_auc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

val_auc_df = val_auc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

val_auc_st = (
    val_auc_df.style
      .set_caption("Table 1: MLP - Summary Validation AUC")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)

dfi.export(val_auc_st, "MLP_table_validation_AUC.png", table_conversion="matplotlib")

# %%
val_auc_st
# Out:
# <style type="text/css">
# #T_2d8e5 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_2d8e5 th {
#   padding: 10px;
# }
# #T_2d8e5  td {
#   padding: 10px;
# }
# #T_2d8e5 th {
#   font-size: 12pt;
# }
# #T_2d8e5 td {
#   font-size: 11pt;
# }
# #T_2d8e5_row0_col0, #T_2d8e5_row0_col1, #T_2d8e5_row0_col2, #T_2d8e5_row1_col0, #T_2d8e5_row1_col1, #T_2d8e5_row1_col2, #T_2d8e5_row2_col0, #T_2d8e5_row2_col1, #T_2d8e5_row2_col2, #T_2d8e5_row3_col0, #T_2d8e5_row3_col1, #T_2d8e5_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_2d8e5">
#   <caption>Table 1: MLP - Summary Validation AUC</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_2d8e5_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_2d8e5_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_2d8e5_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d8e5_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_2d8e5_row0_col0" class="data row0 col0" >0.5194</td>
#       <td id="T_2d8e5_row0_col1" class="data row0 col1" >0.5091</td>
#       <td id="T_2d8e5_row0_col2" class="data row0 col2" >0.5324</td>
#     </tr>
#     <tr>
#       <th id="T_2d8e5_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_2d8e5_row1_col0" class="data row1 col0" >0.5283</td>
#       <td id="T_2d8e5_row1_col1" class="data row1 col1" >0.5862</td>
#       <td id="T_2d8e5_row1_col2" class="data row1 col2" >0.6774</td>
#     </tr>
#     <tr>
#       <th id="T_2d8e5_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_2d8e5_row2_col0" class="data row2 col0" >0.5422</td>
#       <td id="T_2d8e5_row2_col1" class="data row2 col1" >0.5903</td>
#       <td id="T_2d8e5_row2_col2" class="data row2 col2" >0.6053</td>
#     </tr>
#     <tr>
#       <th id="T_2d8e5_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_2d8e5_row3_col0" class="data row3 col0" >0.5093</td>
#       <td id="T_2d8e5_row3_col1" class="data row3 col1" >0.5195</td>
#       <td id="T_2d8e5_row3_col2" class="data row3 col2" >0.5320</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_acc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Test Accuracy")
test_acc_df = test_acc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

test_acc_df = test_acc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

test_acc_st = (
    test_acc_df.style
      .set_caption("Table 2: MLP -  Summary Testing Accuracy")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)
dfi.export(test_acc_st, "MLP_table_test_accuracy.png", table_conversion="matplotlib")

# %%
test_acc_st
# Out:
# <style type="text/css">
# #T_503ee table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_503ee th {
#   padding: 10px;
# }
# #T_503ee  td {
#   padding: 10px;
# }
# #T_503ee th {
#   font-size: 12pt;
# }
# #T_503ee td {
#   font-size: 11pt;
# }
# #T_503ee_row0_col0, #T_503ee_row0_col1, #T_503ee_row0_col2, #T_503ee_row1_col0, #T_503ee_row1_col1, #T_503ee_row1_col2, #T_503ee_row2_col0, #T_503ee_row2_col1, #T_503ee_row2_col2, #T_503ee_row3_col0, #T_503ee_row3_col1, #T_503ee_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_503ee">
#   <caption>Table 2: MLP -  Summary Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_503ee_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_503ee_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_503ee_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_503ee_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_503ee_row0_col0" class="data row0 col0" >0.5317</td>
#       <td id="T_503ee_row0_col1" class="data row0 col1" >0.5697</td>
#       <td id="T_503ee_row0_col2" class="data row0 col2" >0.6781</td>
#     </tr>
#     <tr>
#       <th id="T_503ee_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_503ee_row1_col0" class="data row1 col0" >0.5413</td>
#       <td id="T_503ee_row1_col1" class="data row1 col1" >0.5659</td>
#       <td id="T_503ee_row1_col2" class="data row1 col2" >0.5136</td>
#     </tr>
#     <tr>
#       <th id="T_503ee_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_503ee_row2_col0" class="data row2 col0" >0.5011</td>
#       <td id="T_503ee_row2_col1" class="data row2 col1" >0.5468</td>
#       <td id="T_503ee_row2_col2" class="data row2 col2" >0.6419</td>
#     </tr>
#     <tr>
#       <th id="T_503ee_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_503ee_row3_col0" class="data row3 col0" >0.5350</td>
#       <td id="T_503ee_row3_col1" class="data row3 col1" >0.6098</td>
#       <td id="T_503ee_row3_col2" class="data row3 col2" >0.6927</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_auc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Test AUC")
test_auc_df = test_auc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

test_auc_df = test_auc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

test_auc_st = (
    test_auc_df.style
      .set_caption("Table 2: MLP - Summary Testing Accuracy")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)
dfi.export(test_auc_st, "MLP_table_test_AUC.png", table_conversion="matplotlib")

# %%
test_auc_st
# Out:
# <style type="text/css">
# #T_c6692 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_c6692 th {
#   padding: 10px;
# }
# #T_c6692  td {
#   padding: 10px;
# }
# #T_c6692 th {
#   font-size: 12pt;
# }
# #T_c6692 td {
#   font-size: 11pt;
# }
# #T_c6692_row0_col0, #T_c6692_row0_col1, #T_c6692_row0_col2, #T_c6692_row1_col0, #T_c6692_row1_col1, #T_c6692_row1_col2, #T_c6692_row2_col0, #T_c6692_row2_col1, #T_c6692_row2_col2, #T_c6692_row3_col0, #T_c6692_row3_col1, #T_c6692_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_c6692">
#   <caption>Table 2: MLP - Summary Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_c6692_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_c6692_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_c6692_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6692_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_c6692_row0_col0" class="data row0 col0" >0.5055</td>
#       <td id="T_c6692_row0_col1" class="data row0 col1" >0.5117</td>
#       <td id="T_c6692_row0_col2" class="data row0 col2" >0.5110</td>
#     </tr>
#     <tr>
#       <th id="T_c6692_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_c6692_row1_col0" class="data row1 col0" >0.5272</td>
#       <td id="T_c6692_row1_col1" class="data row1 col1" >0.5996</td>
#       <td id="T_c6692_row1_col2" class="data row1 col2" >0.7265</td>
#     </tr>
#     <tr>
#       <th id="T_c6692_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_c6692_row2_col0" class="data row2 col0" >0.4975</td>
#       <td id="T_c6692_row2_col1" class="data row2 col1" >0.5739</td>
#       <td id="T_c6692_row2_col2" class="data row2 col2" >0.6828</td>
#     </tr>
#     <tr>
#       <th id="T_c6692_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_c6692_row3_col0" class="data row3 col0" >0.5096</td>
#       <td id="T_c6692_row3_col1" class="data row3 col1" >0.5025</td>
#       <td id="T_c6692_row3_col2" class="data row3 col2" >0.5015</td>
#     </tr>
#   </tbody>
# </table>
