# %%
# %load_ext autoreload
# %autoreload 2

# %%
from itertools import product
import pandas as pd
import dataframe_image as dfi

import helper_functions as hf
import Models

# %% [markdown]
# # Load Data

# %%
df = hf.load_data()
df = hf.create_engineered_plus_fundamental_features(df)
df = hf.create_binary_labels(df,[1,20,60])

raw = ['ret','volume']
eng = [
    'mean_20', 'mean_60',
    'vol_20', 'vol_60',
    'mom_20', 'mom_60',
    'ema_12', 'ema_26', 'ema_cross',
    'skew_20', 'skew_60',
    'kurt_20', 'kurt_60',
    'vol_z'
]
fund = [
    'eps',
    'profit_margin',
    'revenue_growth',
    'income_growth',
    'gross_margin',
    'operating_margin',
    'sga_ratio',
    'rd_ratio',
    'cost_ratio',
    'net_income_per_share',
    'tax_burden',
    'nonop_ratio',
    'abnormal_ratio',
    'revenue_per_share',
    'da_ratio',
    'interest_coverage',
    'interest_burden'
]

fund_eng = fund + eng 

#rt = df.pivot(index='date', columns='ticker', values='ret')
# Out:
# /Users/evi/Desktop/ML-Stock-Predictor/helper_functions.py:64: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['revenue_growth'] = df.groupby('ticker')['revenue'].pct_change()
# /Users/evi/Desktop/ML-Stock-Predictor/helper_functions.py:66: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df["income_growth"] = df.groupby("ticker")["net_income"].pct_change()

# %% [markdown]
# # Modeling: Logistic Regression

# %% [markdown]
# ## Run all the models with variations in Features and Horizons

# %%
features_map = {
    "raw": raw,
    "eng": eng,
    "fund": fund,
    "fund_eng": fund_eng
}

# %%
features_sets = ['raw', 'eng', 'fund', 'fund_eng']
targets = ['y_1', 'y_20', 'y_60']

#features_sets = ['raw']
#targets = ['y_1']

res = []

for f, t in product(features_sets, targets):
    print(f, t, type(f), type(t))
    features = features_map[f]
    data = hf.prune(df, features, t)

    train, val, test = hf.time_split(data)
    print(f, t)
    val_auc, val_acc, test_auc, test_acc = Models.run_logistic_regression(train, val, test, features, t)

    res.append({
        "Horizon": t,
        "Features": f,
        "Val AUC": val_auc,
        "Val Accuracy": val_acc,
        "Test AUC": test_auc,
        "Test Accuracy": test_acc
    })

res
# Out:
# raw y_1 <class 'str'> <class 'str'>
# raw y_1
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# raw y_20 <class 'str'> <class 'str'>
# raw y_20
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# raw y_60 <class 'str'> <class 'str'>
# raw y_60
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# eng y_1 <class 'str'> <class 'str'>
# eng y_1
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# eng y_20 <class 'str'> <class 'str'>
# eng y_20
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# eng y_60 <class 'str'> <class 'str'>
# eng y_60
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund y_1 <class 'str'> <class 'str'>
# fund y_1
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund y_20 <class 'str'> <class 'str'>
# fund y_20
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund y_60 <class 'str'> <class 'str'>
# fund y_60
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund_eng y_1 <class 'str'> <class 'str'>
# fund_eng y_1
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund_eng y_20 <class 'str'> <class 'str'>
# fund_eng y_20
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund_eng y_60 <class 'str'> <class 'str'>
# fund_eng y_60
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [{'Horizon': 'y_1',
#   'Features': 'raw',
#   'Val AUC': 0.4923070078208573,
#   'Val Accuracy': 0.5260039499670837,
#   'Test AUC': 0.4985415036119433,
#   'Test Accuracy': 0.5343629343629344},
#  {'Horizon': 'y_20',
#   'Features': 'raw',
#   'Val AUC': 0.4979015938672902,
#   'Val Accuracy': 0.4459685513549682,
#   'Test AUC': 0.5279288362438861,
#   'Test Accuracy': 0.4392240412648576},
#  {'Horizon': 'y_60',
#   'Features': 'raw',
#   'Val AUC': 0.5024241822488832,
#   'Val Accuracy': 0.6263115415657788,
#   'Test AUC': 0.5045861626797885,
#   'Test Accuracy': 0.6927179962894249},
#  {'Horizon': 'y_1',
#   'Features': 'eng',
#   'Val AUC': 0.4993089328350766,
#   'Val Accuracy': 0.4939467312348668,
#   'Test AUC': 0.5067686224404312,
#   'Test Accuracy': 0.5001159554730983},
#  {'Horizon': 'y_20',
#   'Features': 'eng',
#   'Val AUC': 0.4715113895816627,
#   'Val Accuracy': 0.5498475252169833,
#   'Test AUC': 0.5230466047225638,
#   'Test Accuracy': 0.6048130234752861},
#  {'Horizon': 'y_60',
#   'Features': 'eng',
#   'Val AUC': 0.4404432627345193,
#   'Val Accuracy': 0.592201166180758,
#   'Test AUC': 0.5138195597407563,
#   'Test Accuracy': 0.6892337773432726},
#  {'Horizon': 'y_1',
#   'Features': 'fund',
#   'Val AUC': 0.5284216102688157,
#   'Val Accuracy': 0.5178378378378379,
#   'Test AUC': 0.5253763163919414,
#   'Test Accuracy': 0.5423913043478261},
#  {'Horizon': 'y_20',
#   'Features': 'fund',
#   'Val AUC': 0.48633032488334327,
#   'Val Accuracy': 0.5406593406593406,
#   'Test AUC': 0.5719727682632598,
#   'Test Accuracy': 0.5604395604395604},
#  {'Horizon': 'y_60',
#   'Features': 'fund',
#   'Val AUC': 0.46268393832161786,
#   'Val Accuracy': 0.4647727272727273,
#   'Test AUC': 0.6282893181543571,
#   'Test Accuracy': 0.5420454545454545},
#  {'Horizon': 'y_1',
#   'Features': 'fund_eng',
#   'Val AUC': 0.5086787975492754,
#   'Val Accuracy': 0.5050847457627119,
#   'Test AUC': 0.5230820602721429,
#   'Test Accuracy': 0.49204545454545456},
#  {'Horizon': 'y_20',
#   'Features': 'fund_eng',
#   'Val AUC': 0.4492645502645502,
#   'Val Accuracy': 0.43908045977011495,
#   'Test AUC': 0.6192219178082192,
#   'Test Accuracy': 0.5676300578034682},
#  {'Horizon': 'y_60',
#   'Features': 'fund_eng',
#   'Val AUC': 0.4722931562819203,
#   'Val Accuracy': 0.4928571428571429,
#   'Test AUC': 0.6370898251007242,
#   'Test Accuracy': 0.5413173652694611}]

# %%
res_df = pd.DataFrame(res)
val_acc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Val Accuracy")

val_acc_df = val_acc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

val_acc_df = val_acc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

val_acc_st = (
    val_acc_df.style
      .set_caption("Table 1: Logistic - Summary Validation Accuracy")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)

dfi.export(val_acc_st, "Logistic_table_validation_accuracy.png", table_conversion="matplotlib")

# %%
val_acc_st
# Out:
# <style type="text/css">
# #T_0e52c table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_0e52c th {
#   padding: 10px;
# }
# #T_0e52c  td {
#   padding: 10px;
# }
# #T_0e52c th {
#   font-size: 12pt;
# }
# #T_0e52c td {
#   font-size: 11pt;
# }
# #T_0e52c_row0_col0, #T_0e52c_row0_col1, #T_0e52c_row0_col2, #T_0e52c_row1_col0, #T_0e52c_row1_col1, #T_0e52c_row1_col2, #T_0e52c_row2_col0, #T_0e52c_row2_col1, #T_0e52c_row2_col2, #T_0e52c_row3_col0, #T_0e52c_row3_col1, #T_0e52c_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_0e52c">
#   <caption>Table 1: Logistic - Summary Validation Accuracy</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_0e52c_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_0e52c_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_0e52c_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e52c_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_0e52c_row0_col0" class="data row0 col0" >0.4939</td>
#       <td id="T_0e52c_row0_col1" class="data row0 col1" >0.5498</td>
#       <td id="T_0e52c_row0_col2" class="data row0 col2" >0.5922</td>
#     </tr>
#     <tr>
#       <th id="T_0e52c_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_0e52c_row1_col0" class="data row1 col0" >0.5178</td>
#       <td id="T_0e52c_row1_col1" class="data row1 col1" >0.5407</td>
#       <td id="T_0e52c_row1_col2" class="data row1 col2" >0.4648</td>
#     </tr>
#     <tr>
#       <th id="T_0e52c_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_0e52c_row2_col0" class="data row2 col0" >0.5051</td>
#       <td id="T_0e52c_row2_col1" class="data row2 col1" >0.4391</td>
#       <td id="T_0e52c_row2_col2" class="data row2 col2" >0.4929</td>
#     </tr>
#     <tr>
#       <th id="T_0e52c_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_0e52c_row3_col0" class="data row3 col0" >0.5260</td>
#       <td id="T_0e52c_row3_col1" class="data row3 col1" >0.4460</td>
#       <td id="T_0e52c_row3_col2" class="data row3 col2" >0.6263</td>
#     </tr>
#   </tbody>
# </table>

# %%
res_df = pd.DataFrame(res)
val_auc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Val AUC")

val_auc_df = val_auc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

val_auc_df = val_auc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

val_auc_st = (
    val_auc_df.style
      .set_caption("Table 1: Logistic - Summary Validation AUC")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)

#dfi.export(test_st, "random_forest_table_test.png", table_conversion="matplotlib")
dfi.export(val_auc_st, "Logistic_table_validation_AUC.png", table_conversion="matplotlib")

# %%
val_auc_st
# Out:
# <style type="text/css">
# #T_87552 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_87552 th {
#   padding: 10px;
# }
# #T_87552  td {
#   padding: 10px;
# }
# #T_87552 th {
#   font-size: 12pt;
# }
# #T_87552 td {
#   font-size: 11pt;
# }
# #T_87552_row0_col0, #T_87552_row0_col1, #T_87552_row0_col2, #T_87552_row1_col0, #T_87552_row1_col1, #T_87552_row1_col2, #T_87552_row2_col0, #T_87552_row2_col1, #T_87552_row2_col2, #T_87552_row3_col0, #T_87552_row3_col1, #T_87552_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_87552">
#   <caption>Table 1: Logistic - Summary Validation AUC</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_87552_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_87552_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_87552_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87552_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_87552_row0_col0" class="data row0 col0" >0.4993</td>
#       <td id="T_87552_row0_col1" class="data row0 col1" >0.4715</td>
#       <td id="T_87552_row0_col2" class="data row0 col2" >0.4404</td>
#     </tr>
#     <tr>
#       <th id="T_87552_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_87552_row1_col0" class="data row1 col0" >0.5284</td>
#       <td id="T_87552_row1_col1" class="data row1 col1" >0.4863</td>
#       <td id="T_87552_row1_col2" class="data row1 col2" >0.4627</td>
#     </tr>
#     <tr>
#       <th id="T_87552_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_87552_row2_col0" class="data row2 col0" >0.5087</td>
#       <td id="T_87552_row2_col1" class="data row2 col1" >0.4493</td>
#       <td id="T_87552_row2_col2" class="data row2 col2" >0.4723</td>
#     </tr>
#     <tr>
#       <th id="T_87552_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_87552_row3_col0" class="data row3 col0" >0.4923</td>
#       <td id="T_87552_row3_col1" class="data row3 col1" >0.4979</td>
#       <td id="T_87552_row3_col2" class="data row3 col2" >0.5024</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_acc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Test Accuracy")
test_acc_df = test_acc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

test_acc_df = test_acc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

test_acc_st = (
    test_acc_df.style
      .set_caption("Table 2: Logistic - Summary Testing Accuracy")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)
dfi.export(test_acc_st, "Logistic_table_test_accuracy.png", table_conversion="matplotlib")

# %%
test_acc_st
# Out:
# <style type="text/css">
# #T_20813 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_20813 th {
#   padding: 10px;
# }
# #T_20813  td {
#   padding: 10px;
# }
# #T_20813 th {
#   font-size: 12pt;
# }
# #T_20813 td {
#   font-size: 11pt;
# }
# #T_20813_row0_col0, #T_20813_row0_col1, #T_20813_row0_col2, #T_20813_row1_col0, #T_20813_row1_col1, #T_20813_row1_col2, #T_20813_row2_col0, #T_20813_row2_col1, #T_20813_row2_col2, #T_20813_row3_col0, #T_20813_row3_col1, #T_20813_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_20813">
#   <caption>Table 2: Logistic - Summary Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_20813_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_20813_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_20813_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20813_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_20813_row0_col0" class="data row0 col0" >0.5001</td>
#       <td id="T_20813_row0_col1" class="data row0 col1" >0.6048</td>
#       <td id="T_20813_row0_col2" class="data row0 col2" >0.6892</td>
#     </tr>
#     <tr>
#       <th id="T_20813_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_20813_row1_col0" class="data row1 col0" >0.5424</td>
#       <td id="T_20813_row1_col1" class="data row1 col1" >0.5604</td>
#       <td id="T_20813_row1_col2" class="data row1 col2" >0.5420</td>
#     </tr>
#     <tr>
#       <th id="T_20813_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_20813_row2_col0" class="data row2 col0" >0.4920</td>
#       <td id="T_20813_row2_col1" class="data row2 col1" >0.5676</td>
#       <td id="T_20813_row2_col2" class="data row2 col2" >0.5413</td>
#     </tr>
#     <tr>
#       <th id="T_20813_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_20813_row3_col0" class="data row3 col0" >0.5344</td>
#       <td id="T_20813_row3_col1" class="data row3 col1" >0.4392</td>
#       <td id="T_20813_row3_col2" class="data row3 col2" >0.6927</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_auc_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Test AUC")
test_auc_df = test_auc_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

test_auc_df = test_auc_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

test_auc_st = (
    test_auc_df.style
      .set_caption("Table 2: Logistic - Summary Testing Accuracy")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)
dfi.export(test_auc_st, "Logistic_table_test_AUC.png", table_conversion="matplotlib")

# %%
test_auc_st
# Out:
# <style type="text/css">
# #T_549f6 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_549f6 th {
#   padding: 10px;
# }
# #T_549f6  td {
#   padding: 10px;
# }
# #T_549f6 th {
#   font-size: 12pt;
# }
# #T_549f6 td {
#   font-size: 11pt;
# }
# #T_549f6_row0_col0, #T_549f6_row0_col1, #T_549f6_row0_col2, #T_549f6_row1_col0, #T_549f6_row1_col1, #T_549f6_row1_col2, #T_549f6_row2_col0, #T_549f6_row2_col1, #T_549f6_row2_col2, #T_549f6_row3_col0, #T_549f6_row3_col1, #T_549f6_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_549f6">
#   <caption>Table 2: Logistic - Summary Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_549f6_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_549f6_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_549f6_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_549f6_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_549f6_row0_col0" class="data row0 col0" >0.5068</td>
#       <td id="T_549f6_row0_col1" class="data row0 col1" >0.5230</td>
#       <td id="T_549f6_row0_col2" class="data row0 col2" >0.5138</td>
#     </tr>
#     <tr>
#       <th id="T_549f6_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_549f6_row1_col0" class="data row1 col0" >0.5254</td>
#       <td id="T_549f6_row1_col1" class="data row1 col1" >0.5720</td>
#       <td id="T_549f6_row1_col2" class="data row1 col2" >0.6283</td>
#     </tr>
#     <tr>
#       <th id="T_549f6_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_549f6_row2_col0" class="data row2 col0" >0.5231</td>
#       <td id="T_549f6_row2_col1" class="data row2 col1" >0.6192</td>
#       <td id="T_549f6_row2_col2" class="data row2 col2" >0.6371</td>
#     </tr>
#     <tr>
#       <th id="T_549f6_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_549f6_row3_col0" class="data row3 col0" >0.4985</td>
#       <td id="T_549f6_row3_col1" class="data row3 col1" >0.5279</td>
#       <td id="T_549f6_row3_col2" class="data row3 col2" >0.5046</td>
#     </tr>
#   </tbody>
# </table>
