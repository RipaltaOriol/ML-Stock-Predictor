# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from itertools import product

import helper_functions as hf
import Models

# %% [markdown]
# # Load Data

# %%
df = hf.load_data()
df.head()
# Out:
#    index_x ticker  simfinid_x       date    open    high     low   close  \
# 0    16033   AAPL      111052 2019-12-23   70.13   71.06   70.09   71.00
# 1    40152    ABT       63877 2019-12-23   86.31   87.46   86.28   87.35
# 2    95854   ADBE       14099 2019-12-23  328.83  329.88  327.26  328.95
# 3   296720   AMGN       65735 2019-12-23  243.98  244.00  241.59  243.03
# 4   333254   AMZN       62747 2019-12-23   89.41   89.65   89.23   89.65
#
#    adj_close    volume  ...  non-operating_income_loss  interest_expense_net  \
# 0      68.53  98711532  ...                        NaN                   NaN
# 1      78.56   4067769  ...                        NaN                   NaN
# 2     328.95   2210706  ...                        NaN                   NaN
# 3     203.47   1686220  ...                        NaN                   NaN
# 4      89.65  42749860  ...                        NaN                   NaN
#
#    pretax_income_loss_adj  abnormal_gains_losses pretax_income_loss  \
# 0                     NaN                    NaN                NaN
# 1                     NaN                    NaN                NaN
# 2                     NaN                    NaN                NaN
# 3                     NaN                    NaN                NaN
# 4                     NaN                    NaN                NaN
#
#    income_tax_expense_benefit_net income_loss_from_continuing_operations  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                             NaN                                    NaN
# 3                             NaN                                    NaN
# 4                             NaN                                    NaN
#
#   net_extraordinary_gains_losses net_income net_income_common
# 0                            NaN        NaN               NaN
# 1                            NaN        NaN               NaN
# 2                            NaN        NaN               NaN
# 3                            NaN        NaN               NaN
# 4                            NaN        NaN               NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# # Feature Sets

# %% [markdown]
# ## Raw Features

# %%
df = hf.create_raw_features(df)

df[df['ticker'] == "AAPL"].head()[['date', 'ticker', 'adj_close', 'ret']]
# Out:
#           date ticker  adj_close       ret
# 0   2019-12-23   AAPL      68.53       NaN
# 49  2019-12-24   AAPL      68.59  0.000876
# 98  2019-12-26   AAPL      69.96  0.019974
# 147 2019-12-27   AAPL      69.93 -0.000429
# 196 2019-12-30   AAPL      70.34  0.005863

# %% [markdown]
# ## Fundamental Features

# %%
df = hf.create_fundamental_features(df)

df[df['ticker'] == "AAPL"].tail()[['date', 'ticker', 'eps', 'profit_margin', 'revenue_growth']]
# Out:
# /Users/oriolripalta/Desktop/Project DL/helper_functions.py:8: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   from sklearn.preprocessing import StandardScaler
# /Users/oriolripalta/Desktop/Project DL/helper_functions.py:9: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   from sklearn.linear_model import LogisticRegression
#             date ticker       eps  profit_margin  revenue_growth
# 60515 2024-11-19   AAPL  0.966748        0.15523             0.0
# 60564 2024-11-20   AAPL  0.966748        0.15523             0.0
# 60613 2024-11-21   AAPL  0.966748        0.15523             0.0
# 60662 2024-11-22   AAPL  0.966748        0.15523             0.0
# 60711 2024-11-25   AAPL  0.966748        0.15523             0.0

# %% [markdown]
# ## Engineered Features

# %%
df = hf.create_engineered_features(df)

df[df['ticker'] == "AAPL"].head(25)[['date', 'ticker', 'mean_20', 'vol_20', 'ema_cross', 'skew_20', 'kurt_20']]
# Out:
#            date ticker   mean_20    vol_20  ema_cross   skew_20   kurt_20
# 0    2019-12-23   AAPL       NaN       NaN        NaN       NaN       NaN
# 49   2019-12-24   AAPL       NaN       NaN   0.000000       NaN       NaN
# 98   2019-12-26   AAPL       NaN       NaN   0.004786       NaN       NaN
# 147  2019-12-27   AAPL       NaN       NaN   0.117769       NaN       NaN
# 196  2019-12-30   AAPL       NaN       NaN   0.202554       NaN       NaN
# 245  2019-12-31   AAPL       NaN       NaN   0.299379       NaN       NaN
# 294  2020-01-02   AAPL       NaN       NaN   0.413308       NaN       NaN
# 343  2020-01-03   AAPL       NaN       NaN   0.626292       NaN       NaN
# 392  2020-01-06   AAPL       NaN       NaN   0.730182       NaN       NaN
# 441  2020-01-07   AAPL       NaN       NaN   0.848727       NaN       NaN
# 490  2020-01-08   AAPL       NaN       NaN   0.904809       NaN       NaN
# 539  2020-01-09   AAPL       NaN       NaN   1.030972       NaN       NaN
# 588  2020-01-10   AAPL       NaN       NaN   1.241716       NaN       NaN
# 637  2020-01-13   AAPL       NaN       NaN   1.406239       NaN       NaN
# 686  2020-01-14   AAPL       NaN       NaN   1.646749       NaN       NaN
# 735  2020-01-15   AAPL       NaN       NaN   1.734250       NaN       NaN
# 784  2020-01-16   AAPL       NaN       NaN   1.757516       NaN       NaN
# 833  2020-01-17   AAPL       NaN       NaN   1.830700       NaN       NaN
# 882  2020-01-21   AAPL       NaN       NaN   1.934185       NaN       NaN
# 931  2020-01-22   AAPL       NaN       NaN   1.951739       NaN       NaN
# 980  2020-01-23   AAPL  0.005918  0.010791   1.964788  0.021504 -0.901141
# 1029 2020-01-24   AAPL  0.005732  0.010915   1.982137  0.053156 -0.989407
# 1078 2020-01-27   AAPL  0.003262  0.012926   1.955591 -0.577591  0.755174
# 1127 2020-01-28   AAPL  0.004698  0.014043   1.732222 -0.460057  0.420057
# 1176 2020-01-29   AAPL  0.005449  0.014502   1.705797 -0.509303  0.161981

# %%
list(df.columns)
# Out:
# ['index_x',
#  'ticker',
#  'simfinid_x',
#  'date',
#  'open',
#  'high',
#  'low',
#  'close',
#  'adj_close',
#  'volume',
#  'dividend',
#  'shares_outstanding',
#  'index_y',
#  'simfinid_y',
#  'currency',
#  'fiscal_year',
#  'fiscal_period',
#  'report_date',
#  'publish_date',
#  'restated_date',
#  'shares_basic',
#  'shares_diluted',
#  'revenue',
#  'cost_of_revenue',
#  'gross_profit',
#  'operating_expenses',
#  'selling_general_&_administrative',
#  'research_&_development',
#  'depreciation_&_amortization',
#  'operating_income_loss',
#  'non-operating_income_loss',
#  'interest_expense_net',
#  'pretax_income_loss_adj',
#  'abnormal_gains_losses',
#  'pretax_income_loss',
#  'income_tax_expense_benefit_net',
#  'income_loss_from_continuing_operations',
#  'net_extraordinary_gains_losses',
#  'net_income',
#  'net_income_common',
#  'ret',
#  'eps',
#  'profit_margin',
#  'revenue_growth',
#  'income_growth',
#  'gross_margin',
#  'operating_margin',
#  'sga_ratio',
#  'rd_ratio',
#  'cost_ratio',
#  'net_income_per_share',
#  'tax_burden',
#  'nonop_ratio',
#  'abnormal_ratio',
#  'revenue_per_share',
#  'da_ratio',
#  'interest_coverage',
#  'interest_burden',
#  'mean_20',
#  'mean_60',
#  'vol_20',
#  'vol_60',
#  'mom_20',
#  'mom_60',
#  'ema_12',
#  'ema_26',
#  'ema_cross',
#  'skew_20',
#  'skew_60',
#  'kurt_20',
#  'kurt_60',
#  'vol_z']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# <h5 style="color:red">Check multicolinearity</h5>

# %%
raw = ['ret','volume']

eng = [
    'mean_20', 'mean_60',
    'vol_20', 'vol_60',
    'mom_20', 'mom_60',
    'ema_12', 'ema_26', 'ema_cross',
    'skew_20', 'skew_60',
    'kurt_20', 'kurt_60',
    'vol_z'
]

fund = [
    'eps',
    'profit_margin',
    'revenue_growth',
    'income_growth',
    'gross_margin',
    'operating_margin',
    'sga_ratio',
    'rd_ratio',
    'cost_ratio',
    'net_income_per_share',
    'tax_burden',
    'nonop_ratio',
    'abnormal_ratio',
    'revenue_per_share',
    'da_ratio',
    'interest_coverage',
    'interest_burden'
]

fund_eng = fund + eng

# %% [markdown]
# # Binary Labels

# %%
horizons = [1, 20, 60]

horizon_cols = [f'y_{h}' for h in horizons]

df = hf.create_binary_labels(df, horizons)

df[df["ticker"] == "AAPL"].tail(30)[['date', 'ret'] + horizon_cols]
# Out:
#             date       ret  y_1  y_20  y_60
# 59290 2024-10-15  0.011043  0.0   0.0   NaN
# 59339 2024-10-16 -0.008858  1.0   0.0   NaN
# 59388 2024-10-17  0.001605  1.0   0.0   NaN
# 59437 2024-10-18  0.012258  1.0   0.0   NaN
# 59486 2024-10-21  0.006290  0.0   0.0   NaN
# 59535 2024-10-22 -0.002594  0.0   0.0   NaN
# 59584 2024-10-23 -0.021615  0.0   0.0   NaN
# 59633 2024-10-24 -0.000828  1.0   0.0   NaN
# 59682 2024-10-25  0.003620  1.0   0.0   NaN
# 59731 2024-10-28  0.008604  1.0   0.0   NaN
# 59780 2024-10-29  0.001163  0.0   NaN   NaN
# 59829 2024-10-30 -0.015277  0.0   NaN   NaN
# 59878 2024-10-31 -0.018223  0.0   NaN   NaN
# 59927 2024-11-01 -0.013264  0.0   NaN   NaN
# 59976 2024-11-04 -0.004060  1.0   NaN   NaN
# 60025 2024-11-05  0.006522  0.0   NaN   NaN
# 60074 2024-11-06 -0.003285  1.0   NaN   NaN
# 60123 2024-11-07  0.021355  0.0   NaN   NaN
# 60172 2024-11-08 -0.001194  0.0   NaN   NaN
# 60221 2024-11-11 -0.011994  0.0   NaN   NaN
# 60270 2024-11-12  0.000000  1.0   NaN   NaN
# 60319 2024-11-13  0.003942  1.0   NaN   NaN
# 60368 2024-11-14  0.013787  0.0   NaN   NaN
# 60417 2024-11-15 -0.014128  1.0   NaN   NaN
# 60466 2024-11-18  0.013437  1.0   NaN   NaN
# 60515 2024-11-19  0.001145  1.0   NaN   NaN
# 60564 2024-11-20  0.003168  0.0   NaN   NaN
# 60613 2024-11-21 -0.002105  1.0   NaN   NaN
# 60662 2024-11-22  0.005890  1.0   NaN   NaN
# 60711 2024-11-25  0.013065  NaN   NaN   NaN

# %% [markdown]
# ### `NOTE: we can use sklearn train-test split`

# %%
train, val, test = hf.time_split(df)
len(train), len(val), len(test)
# Out:
# (42581, 9114, 9065)

# %% [markdown]
# # Modeling: Logistic Regression

# %% [markdown]
# ## Horizon 1 days

# %%
TARGET = "y_1"

# %% [markdown]
# ### Raw Features

# %%
data = hf.prune(df, raw, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, raw, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.4923070078208573, 0.4985415036119433)

# %% [markdown]
# ### Features Eng

# %%
data = hf.prune(df, eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, eng, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.49965201317710106, 0.5042357262457207)

# %% [markdown]
# ### Features Fund

# %%
data = hf.prune(df, fund, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.5093368795320723, 0.5039061800930102)

# %% [markdown]
# ### Features Fund & Eng

# %%
data = hf.prune(df, fund_eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund_eng, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.5067229253207568, 0.5028364861844177)

# %% [markdown]
# ## Horizon 20 days

# %%
TARGET = "y_20"

# %% [markdown]
# ### Features Raw

# %%
data = hf.prune(df, raw, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, raw, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.4979015938672902, 0.5279288362438861)

# %% [markdown]
# ### Features Eng

# %%
data = hf.prune(df, eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, eng, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.4910048156287877, 0.5230469538782763)

# %% [markdown]
# ### Features Fund

# %%
data = hf.prune(df, fund, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.5285954153269234, 0.4742475486393481)

# %% [markdown]
# ### Features Fund & Eng

# %%
data = hf.prune(df, fund_eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund_eng, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.5025293255131965, 0.5147096701169483)

# %% [markdown]
# ## Horizon 60 days

# %%
TARGET = "y_60"

# %% [markdown]
# ### Features Raw

# %%
data = hf.prune(df, eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, eng, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.4983610356720456, 0.5155989360767208)

# %% [markdown]
# ### Features Eng

# %%
data = hf.prune(df, eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, eng, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.4983610356720456, 0.5155989360767208)

# %% [markdown]
# ### Features Fund

# %%
data = hf.prune(df, fund, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.46037978450658146, 0.47889826190038687)

# %% [markdown]
# ### Features Fund & Eng

# %%
data = hf.prune(df, fund_eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund_eng, TARGET)
# Out:
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# (0.48361722766838544, 0.5006284541505793)

# %% [markdown]
# # Results

# %%
features_map = {
    "raw": raw,
    "eng": eng,
    "fund": fund,
    "fund_eng": fund_eng
}

# %%
features_sets = ['raw', 'eng', 'fund', 'fund_eng']
targets = ['y_1', 'y_20', 'y_60']
res = []

for f, t in product(features_sets, targets):
    print(f, t, type(f), type(t))
    features = features_map[f]
    data = hf.prune(df, features, t)

    train, val, test = hf.time_split(data)
    print(f, t)
    val_acc, test_acc = Models.run_logistic_regression(train, val, test, features, t)

    res.append({
        "Horizon": t,
        "Features": f,
        "Val Accuracy": val_acc,
        "Test Accuracy": test_acc,
    })

res
# Out:
# raw y_1 <class 'str'> <class 'str'>
# raw y_1
# raw y_20 <class 'str'> <class 'str'>
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# raw y_20
# raw y_60 <class 'str'> <class 'str'>
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# raw y_60
# eng y_1 <class 'str'> <class 'str'>
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# eng y_1
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# eng y_20 <class 'str'> <class 'str'>
# eng y_20
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# eng y_60 <class 'str'> <class 'str'>
# eng y_60
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund y_1 <class 'str'> <class 'str'>
# fund y_1
# fund y_20 <class 'str'> <class 'str'>
# fund y_20
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund y_60 <class 'str'> <class 'str'>
# fund y_60
# fund_eng y_1 <class 'str'> <class 'str'>
# fund_eng y_1
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund_eng y_20 <class 'str'> <class 'str'>
# fund_eng y_20
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund_eng y_60 <class 'str'> <class 'str'>
# fund_eng y_60
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/oriolripalta/Desktop/Project DL/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [{'Horizon': 'y_1',
#   'Features': 'raw',
#   'Val Accuracy': 0.4923070078208573,
#   'Test Accuracy': 0.4985415036119433},
#  {'Horizon': 'y_20',
#   'Features': 'raw',
#   'Val Accuracy': 0.4979015938672902,
#   'Test Accuracy': 0.5279288362438861},
#  {'Horizon': 'y_60',
#   'Features': 'raw',
#   'Val Accuracy': 0.5024241822488832,
#   'Test Accuracy': 0.5045861626797885},
#  {'Horizon': 'y_1',
#   'Features': 'eng',
#   'Val Accuracy': 0.4993089328350766,
#   'Test Accuracy': 0.5067686224404312},
#  {'Horizon': 'y_20',
#   'Features': 'eng',
#   'Val Accuracy': 0.4715113895816627,
#   'Test Accuracy': 0.5230466047225638},
#  {'Horizon': 'y_60',
#   'Features': 'eng',
#   'Val Accuracy': 0.4404432627345193,
#   'Test Accuracy': 0.5138195597407563},
#  {'Horizon': 'y_1',
#   'Features': 'fund',
#   'Val Accuracy': 0.5284216102688157,
#   'Test Accuracy': 0.5253763163919414},
#  {'Horizon': 'y_20',
#   'Features': 'fund',
#   'Val Accuracy': 0.48633032488334327,
#   'Test Accuracy': 0.5719727682632598},
#  {'Horizon': 'y_60',
#   'Features': 'fund',
#   'Val Accuracy': 0.46268393832161786,
#   'Test Accuracy': 0.6282893181543571},
#  {'Horizon': 'y_1',
#   'Features': 'fund_eng',
#   'Val Accuracy': 0.5086787975492754,
#   'Test Accuracy': 0.5230820602721429},
#  {'Horizon': 'y_20',
#   'Features': 'fund_eng',
#   'Val Accuracy': 0.4492645502645502,
#   'Test Accuracy': 0.6192219178082192},
#  {'Horizon': 'y_60',
#   'Features': 'fund_eng',
#   'Val Accuracy': 0.4722699414987464,
#   'Test Accuracy': 0.6370898251007242}]

# %%
res_df = pd.DataFrame(res)
val_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Val Accuracy")
val_df
# Out:
# Horizon        y_1      y_20      y_60
# Features
# eng       0.499309  0.471511  0.440443
# fund      0.528422  0.486330  0.462684
# fund_eng  0.508679  0.449265  0.472270
# raw       0.492307  0.497902  0.502424

# %%
test_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Test Accuracy")
test_df
# Out:
# Horizon        y_1      y_20      y_60
# Features
# eng       0.506769  0.523047  0.513820
# fund      0.525376  0.571973  0.628289
# fund_eng  0.523082  0.619222  0.637090
# raw       0.498542  0.527929  0.504586

# %%
val_df = val_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

val_df = val_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

val_st = (
    val_df.style
      .set_caption("Table 1: Summary Validation AUC")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)
val_st
# Out:
# <style type="text/css">
# #T_0a448 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_0a448 th {
#   padding: 10px;
# }
# #T_0a448  td {
#   padding: 10px;
# }
# #T_0a448 th {
#   font-size: 12pt;
# }
# #T_0a448 td {
#   font-size: 11pt;
# }
# #T_0a448_row0_col0, #T_0a448_row0_col1, #T_0a448_row0_col2, #T_0a448_row1_col0, #T_0a448_row1_col1, #T_0a448_row1_col2, #T_0a448_row2_col0, #T_0a448_row2_col1, #T_0a448_row2_col2, #T_0a448_row3_col0, #T_0a448_row3_col1, #T_0a448_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_0a448">
#   <caption>Table 1: Summary Validation AUC</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_0a448_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_0a448_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_0a448_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a448_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_0a448_row0_col0" class="data row0 col0" >0.4993</td>
#       <td id="T_0a448_row0_col1" class="data row0 col1" >0.4715</td>
#       <td id="T_0a448_row0_col2" class="data row0 col2" >0.4404</td>
#     </tr>
#     <tr>
#       <th id="T_0a448_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_0a448_row1_col0" class="data row1 col0" >0.5284</td>
#       <td id="T_0a448_row1_col1" class="data row1 col1" >0.4863</td>
#       <td id="T_0a448_row1_col2" class="data row1 col2" >0.4627</td>
#     </tr>
#     <tr>
#       <th id="T_0a448_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_0a448_row2_col0" class="data row2 col0" >0.5087</td>
#       <td id="T_0a448_row2_col1" class="data row2 col1" >0.4493</td>
#       <td id="T_0a448_row2_col2" class="data row2 col2" >0.4723</td>
#     </tr>
#     <tr>
#       <th id="T_0a448_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_0a448_row3_col0" class="data row3 col0" >0.4923</td>
#       <td id="T_0a448_row3_col1" class="data row3 col1" >0.4979</td>
#       <td id="T_0a448_row3_col2" class="data row3 col2" >0.5024</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_df = test_df.rename(columns={
    "y_1": "1-day horizon",
    "y_20": "20-day horizon",
    "y_60": "60-day horizon"
})

test_df = test_df.rename(index={
    "raw": "Raw",
    "eng": "Engineered",
    "fund": "Fundamental",
    "fund_eng": "Fund + Eng"
})

test_st = (
    test_df.style
      .set_caption("Table 1: Summary Testing AUC")
      .format("{:.4f}")              # numeric formatting
      .set_table_styles([
          {"selector": "table", "props": "width:100%; border-collapse:separate; border-spacing:10px;"},
          {"selector": "th, td", "props": "padding:10px;"},
          {"selector": "th", "props": "font-size:12pt;"},
          {"selector": "td", "props": "font-size:11pt;"},
      ])
      .set_properties(**{"min-width": "120px"})
)
test_st
# Out:
# <style type="text/css">
# #T_850f9 table {
#   width: 100%;
#   border-collapse: separate;
#   border-spacing: 10px;
# }
# #T_850f9 th {
#   padding: 10px;
# }
# #T_850f9  td {
#   padding: 10px;
# }
# #T_850f9 th {
#   font-size: 12pt;
# }
# #T_850f9 td {
#   font-size: 11pt;
# }
# #T_850f9_row0_col0, #T_850f9_row0_col1, #T_850f9_row0_col2, #T_850f9_row1_col0, #T_850f9_row1_col1, #T_850f9_row1_col2, #T_850f9_row2_col0, #T_850f9_row2_col1, #T_850f9_row2_col2, #T_850f9_row3_col0, #T_850f9_row3_col1, #T_850f9_row3_col2 {
#   min-width: 120px;
# }
# </style>
# <table id="T_850f9">
#   <caption>Table 1: Summary Testing AUC</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_850f9_level0_col0" class="col_heading level0 col0" >1-day horizon</th>
#       <th id="T_850f9_level0_col1" class="col_heading level0 col1" >20-day horizon</th>
#       <th id="T_850f9_level0_col2" class="col_heading level0 col2" >60-day horizon</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Features</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_850f9_level0_row0" class="row_heading level0 row0" >Engineered</th>
#       <td id="T_850f9_row0_col0" class="data row0 col0" >0.5068</td>
#       <td id="T_850f9_row0_col1" class="data row0 col1" >0.5230</td>
#       <td id="T_850f9_row0_col2" class="data row0 col2" >0.5138</td>
#     </tr>
#     <tr>
#       <th id="T_850f9_level0_row1" class="row_heading level0 row1" >Fundamental</th>
#       <td id="T_850f9_row1_col0" class="data row1 col0" >0.5254</td>
#       <td id="T_850f9_row1_col1" class="data row1 col1" >0.5720</td>
#       <td id="T_850f9_row1_col2" class="data row1 col2" >0.6283</td>
#     </tr>
#     <tr>
#       <th id="T_850f9_level0_row2" class="row_heading level0 row2" >Fund + Eng</th>
#       <td id="T_850f9_row2_col0" class="data row2 col0" >0.5231</td>
#       <td id="T_850f9_row2_col1" class="data row2 col1" >0.6192</td>
#       <td id="T_850f9_row2_col2" class="data row2 col2" >0.6371</td>
#     </tr>
#     <tr>
#       <th id="T_850f9_level0_row3" class="row_heading level0 row3" >Raw</th>
#       <td id="T_850f9_row3_col0" class="data row3 col0" >0.4985</td>
#       <td id="T_850f9_row3_col1" class="data row3 col1" >0.5279</td>
#       <td id="T_850f9_row3_col2" class="data row3 col2" >0.5046</td>
#     </tr>
#   </tbody>
# </table>

# %%
import dataframe_image as dfi
# dfi.export(styled, "table1.png")
dfi.export(test_st, "table1.png", table_conversion="matplotlib")
dfi.export(val_st, "table2.png", table_conversion="matplotlib")
