# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from itertools import product

import helper_functions as hf
import Models

# %% [markdown]
# # Load Data

# %%
df = hf.load_data()
df.head()
# Out:
#    index_x ticker  simfinid_x       date    open    high     low   close  \
# 0    16033   AAPL      111052 2019-12-23   70.13   71.06   70.09   71.00
# 1    40152    ABT       63877 2019-12-23   86.31   87.46   86.28   87.35
# 2    95854   ADBE       14099 2019-12-23  328.83  329.88  327.26  328.95
# 3   296720   AMGN       65735 2019-12-23  243.98  244.00  241.59  243.03
# 4   333254   AMZN       62747 2019-12-23   89.41   89.65   89.23   89.65
#
#    adj_close    volume  ...  non-operating_income_loss  interest_expense_net  \
# 0      68.53  98711532  ...                        NaN                   NaN
# 1      78.56   4067769  ...                        NaN                   NaN
# 2     328.95   2210706  ...                        NaN                   NaN
# 3     203.47   1686220  ...                        NaN                   NaN
# 4      89.65  42749860  ...                        NaN                   NaN
#
#    pretax_income_loss_adj  abnormal_gains_losses pretax_income_loss  \
# 0                     NaN                    NaN                NaN
# 1                     NaN                    NaN                NaN
# 2                     NaN                    NaN                NaN
# 3                     NaN                    NaN                NaN
# 4                     NaN                    NaN                NaN
#
#    income_tax_expense_benefit_net income_loss_from_continuing_operations  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                             NaN                                    NaN
# 3                             NaN                                    NaN
# 4                             NaN                                    NaN
#
#   net_extraordinary_gains_losses net_income net_income_common
# 0                            NaN        NaN               NaN
# 1                            NaN        NaN               NaN
# 2                            NaN        NaN               NaN
# 3                            NaN        NaN               NaN
# 4                            NaN        NaN               NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# # Feature Sets

# %% [markdown]
# ## Raw Features

# %%
df = hf.create_raw_features(df)

df[df['ticker'] == "AAPL"].head()[['date', 'ticker', 'adj_close', 'ret']]
# Out:
#           date ticker  adj_close       ret
# 0   2019-12-23   AAPL      68.53       NaN
# 49  2019-12-24   AAPL      68.59  0.000876
# 98  2019-12-26   AAPL      69.96  0.019974
# 147 2019-12-27   AAPL      69.93 -0.000429
# 196 2019-12-30   AAPL      70.34  0.005863

# %% [markdown]
# ## Fundamental Features

# %%
df = hf.create_fundamental_features(df)

df[df['ticker'] == "AAPL"].tail()[['date', 'ticker', 'eps', 'profit_margin', 'revenue_growth']]
# Out:
# /Users/uri/Desktop/BU/ML-Stock-Predictor/helper_functions.py:64: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['revenue_growth'] = df.groupby('ticker')['revenue'].pct_change()
# /Users/uri/Desktop/BU/ML-Stock-Predictor/helper_functions.py:66: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df["income_growth"] = df.groupby("ticker")["net_income"].pct_change()
#             date ticker       eps  profit_margin  revenue_growth
# 60515 2024-11-19   AAPL  0.966748        0.15523             0.0
# 60564 2024-11-20   AAPL  0.966748        0.15523             0.0
# 60613 2024-11-21   AAPL  0.966748        0.15523             0.0
# 60662 2024-11-22   AAPL  0.966748        0.15523             0.0
# 60711 2024-11-25   AAPL  0.966748        0.15523             0.0

# %% [markdown]
# ## Engineered Features

# %%
df = hf.create_engineered_features(df)

df[df['ticker'] == "AAPL"].head(25)[['date', 'ticker', 'mean_20', 'vol_20', 'ema_cross', 'skew_20', 'kurt_20']]
# Out:
#            date ticker   mean_20    vol_20  ema_cross   skew_20   kurt_20
# 0    2019-12-23   AAPL       NaN       NaN        NaN       NaN       NaN
# 49   2019-12-24   AAPL       NaN       NaN   0.000000       NaN       NaN
# 98   2019-12-26   AAPL       NaN       NaN   0.004786       NaN       NaN
# 147  2019-12-27   AAPL       NaN       NaN   0.117769       NaN       NaN
# 196  2019-12-30   AAPL       NaN       NaN   0.202554       NaN       NaN
# 245  2019-12-31   AAPL       NaN       NaN   0.299379       NaN       NaN
# 294  2020-01-02   AAPL       NaN       NaN   0.413308       NaN       NaN
# 343  2020-01-03   AAPL       NaN       NaN   0.626292       NaN       NaN
# 392  2020-01-06   AAPL       NaN       NaN   0.730182       NaN       NaN
# 441  2020-01-07   AAPL       NaN       NaN   0.848727       NaN       NaN
# 490  2020-01-08   AAPL       NaN       NaN   0.904809       NaN       NaN
# 539  2020-01-09   AAPL       NaN       NaN   1.030972       NaN       NaN
# 588  2020-01-10   AAPL       NaN       NaN   1.241716       NaN       NaN
# 637  2020-01-13   AAPL       NaN       NaN   1.406239       NaN       NaN
# 686  2020-01-14   AAPL       NaN       NaN   1.646749       NaN       NaN
# 735  2020-01-15   AAPL       NaN       NaN   1.734250       NaN       NaN
# 784  2020-01-16   AAPL       NaN       NaN   1.757516       NaN       NaN
# 833  2020-01-17   AAPL       NaN       NaN   1.830700       NaN       NaN
# 882  2020-01-21   AAPL       NaN       NaN   1.934185       NaN       NaN
# 931  2020-01-22   AAPL       NaN       NaN   1.951739       NaN       NaN
# 980  2020-01-23   AAPL  0.005918  0.010791   1.964788  0.021504 -0.901141
# 1029 2020-01-24   AAPL  0.005732  0.010915   1.982137  0.053156 -0.989407
# 1078 2020-01-27   AAPL  0.003262  0.012926   1.955591 -0.577591  0.755174
# 1127 2020-01-28   AAPL  0.004698  0.014043   1.732222 -0.460057  0.420057
# 1176 2020-01-29   AAPL  0.005449  0.014502   1.705797 -0.509303  0.161981

# %%
list(df.columns)
# Out:
# ['index_x',
#  'ticker',
#  'simfinid_x',
#  'date',
#  'open',
#  'high',
#  'low',
#  'close',
#  'adj_close',
#  'volume',
#  'dividend',
#  'shares_outstanding',
#  'index_y',
#  'simfinid_y',
#  'currency',
#  'fiscal_year',
#  'fiscal_period',
#  'report_date',
#  'publish_date',
#  'restated_date',
#  'shares_basic',
#  'shares_diluted',
#  'revenue',
#  'cost_of_revenue',
#  'gross_profit',
#  'operating_expenses',
#  'selling_general_&_administrative',
#  'research_&_development',
#  'depreciation_&_amortization',
#  'operating_income_loss',
#  'non-operating_income_loss',
#  'interest_expense_net',
#  'pretax_income_loss_adj',
#  'abnormal_gains_losses',
#  'pretax_income_loss',
#  'income_tax_expense_benefit_net',
#  'income_loss_from_continuing_operations',
#  'net_extraordinary_gains_losses',
#  'net_income',
#  'net_income_common',
#  'ret',
#  'eps',
#  'profit_margin',
#  'revenue_growth',
#  'income_growth',
#  'gross_margin',
#  'operating_margin',
#  'sga_ratio',
#  'rd_ratio',
#  'cost_ratio',
#  'net_income_per_share',
#  'tax_burden',
#  'nonop_ratio',
#  'abnormal_ratio',
#  'revenue_per_share',
#  'da_ratio',
#  'interest_coverage',
#  'interest_burden',
#  'mean_20',
#  'mean_60',
#  'vol_20',
#  'vol_60',
#  'mom_20',
#  'mom_60',
#  'ema_12',
#  'ema_26',
#  'ema_cross',
#  'skew_20',
#  'skew_60',
#  'kurt_20',
#  'kurt_60',
#  'vol_z']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# <h5 style="color:red">Check multicolinearity</h5>

# %%
raw = ['ret', 'volume']

eng = ['mean_20', 'mean_60', 'vol_20', 'vol_60',
       'mom_20', 'mom_60', 'ema_cross', 'skew_20',
       'skew_60', 'kurt_20', 'kurt_60']

fund = ['eps', 'profit_margin', 'revenue_growth']

fund_eng = fund + eng

# %% [markdown]
# # Binary Labels

# %%
horizons = [1, 20, 60]

horizon_cols = [f'y_{h}' for h in horizons]

df = hf.create_binary_labels(df, horizons)

df[df["ticker"] == "AAPL"].tail(30)[['date', 'ret'] + horizon_cols]
# Out:
#             date       ret  y_1  y_20  y_60
# 59290 2024-10-15  0.011043  0.0   0.0   NaN
# 59339 2024-10-16 -0.008858  1.0   0.0   NaN
# 59388 2024-10-17  0.001605  1.0   0.0   NaN
# 59437 2024-10-18  0.012258  1.0   0.0   NaN
# 59486 2024-10-21  0.006290  0.0   0.0   NaN
# 59535 2024-10-22 -0.002594  0.0   0.0   NaN
# 59584 2024-10-23 -0.021615  0.0   0.0   NaN
# 59633 2024-10-24 -0.000828  1.0   0.0   NaN
# 59682 2024-10-25  0.003620  1.0   0.0   NaN
# 59731 2024-10-28  0.008604  1.0   0.0   NaN
# 59780 2024-10-29  0.001163  0.0   NaN   NaN
# 59829 2024-10-30 -0.015277  0.0   NaN   NaN
# 59878 2024-10-31 -0.018223  0.0   NaN   NaN
# 59927 2024-11-01 -0.013264  0.0   NaN   NaN
# 59976 2024-11-04 -0.004060  1.0   NaN   NaN
# 60025 2024-11-05  0.006522  0.0   NaN   NaN
# 60074 2024-11-06 -0.003285  1.0   NaN   NaN
# 60123 2024-11-07  0.021355  0.0   NaN   NaN
# 60172 2024-11-08 -0.001194  0.0   NaN   NaN
# 60221 2024-11-11 -0.011994  0.0   NaN   NaN
# 60270 2024-11-12  0.000000  1.0   NaN   NaN
# 60319 2024-11-13  0.003942  1.0   NaN   NaN
# 60368 2024-11-14  0.013787  0.0   NaN   NaN
# 60417 2024-11-15 -0.014128  1.0   NaN   NaN
# 60466 2024-11-18  0.013437  1.0   NaN   NaN
# 60515 2024-11-19  0.001145  1.0   NaN   NaN
# 60564 2024-11-20  0.003168  0.0   NaN   NaN
# 60613 2024-11-21 -0.002105  1.0   NaN   NaN
# 60662 2024-11-22  0.005890  1.0   NaN   NaN
# 60711 2024-11-25  0.013065  NaN   NaN   NaN

# %% [markdown]
# ### `NOTE: we can use sklearn train-test split`

# %%
train, val, test = hf.time_split(df)
len(train), len(val), len(test)
# Out:
# (42581, 9114, 9065)

# %% [markdown]
# # Modeling: Logistic Regression

# %% [markdown]
# ## Horizon 1 days

# %%
TARGET = "y_1"

# %% [markdown]
# ### Raw Features

# %%
data = hf.prune(df, raw, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, raw, TARGET)
# Out:
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Test AUC: 0.4985415036119433
# Test accuracy: 0.5343629343629344
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.07      0.13      4232
#          1.0       0.54      0.94      0.68      4833
#
#     accuracy                           0.53      9065
#    macro avg       0.52      0.51      0.41      9065
# weighted avg       0.52      0.53      0.42      9065
#
# Coefficients:  [-0.0665677   0.00937894]
# done
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[171], line 5
#       1 data = hf.prune(df, raw, TARGET)
#       3 train, val, test = hf.time_split(data)
# ----> 5 Models.run_logistic_regression(train, val, test, raw, TARGET)
#
# File ~/Desktop/BU/ML-Stock-Predictor/Models.py:42, in run_logistic_regression(train, val, test, feature_cols, target_col)
#      40 cvals = [0.01, 0.1, 1.0, 10.0]
#      41 class_weights = [None, "balanced"]
# ---> 42 penalties = ["l2", None]
#      44 best_auc = -np.inf
#      45 best_params = None
#
# File ~/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/pipeline.py:1189, in Pipeline.score(self, X, y, sample_weight, **params)
#    1187     if sample_weight is not None:
#    1188         score_params["sample_weight"] = sample_weight
# -> 1189     return self.steps[-1][1].score(Xt, y, **score_params)
#    1191 # metadata routing is enabled.
#    1192 routed_params = process_routing(
#    1193     self, "score", sample_weight=sample_weight, **params
#    1194 )
#
# File ~/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/base.py:548, in ClassifierMixin.score(self, X, y, sample_weight)
#     523 """
#     524 Return :ref:`accuracy <accuracy_score>` on provided data and labels.
#     525
#    (...)    544     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     545 """
#     546 from .metrics import accuracy_score
# --> 548 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:359, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     357 # Compute accuracy for each possible representation
#     358 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 359 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     360 check_consistent_length(y_true, y_pred, sample_weight)
#     362 if y_type.startswith("multilabel"):
#
# File ~/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:97, in _check_targets(y_true, y_pred)
#      70 """Check that y_true and y_pred belong to the same classification task.
#      71
#      72 This converts multiclass or binary types to a common shape, and raises a
#    (...)     94 y_pred : array or indicator matrix
#      95 """
#      96 xp, _ = get_namespace(y_true, y_pred)
# ---> 97 check_consistent_length(y_true, y_pred)
#      98 type_true = type_of_target(y_true, input_name="y_true")
#      99 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/utils/validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [9065, 51597]

# %% [markdown]
# ### Features Eng

# %%
data = hf.prune(df, eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, eng, TARGET)
# Out:
# Test AUC: 0.5042326455210047
# Test accuracy: 0.5257421150278293
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.07      0.12      4010
#          1.0       0.53      0.92      0.67      4614
#
#     accuracy                           0.53      8624
#    macro avg       0.49      0.50      0.40      8624
# weighted avg       0.49      0.53      0.42      8624

# %% [markdown]
# ### Features Fund

# %%
data = hf.prune(df, fund, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund, TARGET)
# Out:
# Test AUC: 0.5039061800930102
# Test accuracy: 0.5332406471183013
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.02      0.03      3711
#          1.0       0.53      0.99      0.69      4201
#
#     accuracy                           0.53      7912
#    macro avg       0.56      0.50      0.36      7912
# weighted avg       0.56      0.53      0.38      7912

# %% [markdown]
# ### Features Fund & Eng

# %%
data = hf.prune(df, fund_eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund_eng, TARGET)
# Out:
# Test AUC: 0.5028364861844177
# Test accuracy: 0.5046247357293869
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.58      0.53      3546
#          1.0       0.54      0.43      0.48      4022
#
#     accuracy                           0.50      7568
#    macro avg       0.51      0.51      0.50      7568
# weighted avg       0.51      0.50      0.50      7568

# %% [markdown]
# ## Horizon 20 days

# %%
TARGET = "y_20"

# %% [markdown]
# ### Features Raw

# %%
data = hf.prune(df, raw, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, raw, TARGET)
# Out:
# Test AUC: 0.5279288362438861
# Test accuracy: 0.4392240412648576
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.84      0.54      3480
#          1.0       0.64      0.19      0.29      5438
#
#     accuracy                           0.44      8918
#    macro avg       0.52      0.51      0.41      8918
# weighted avg       0.54      0.44      0.39      8918

# %% [markdown]
# ### Features Eng

# %%
data = hf.prune(df, eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, eng, TARGET)
# Out:
# Test AUC: 0.5230507945911125
# Test accuracy: 0.6059926860917777
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.02      0.05      3355
#          1.0       0.61      0.99      0.75      5122
#
#     accuracy                           0.61      8477
#    macro avg       0.58      0.51      0.40      8477
# weighted avg       0.58      0.61      0.47      8477

# %% [markdown]
# ### Features Fund

# %%
data = hf.prune(df, fund, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund, TARGET)
# Out:
# Test AUC: 0.4742475486393481
# Test accuracy: 0.5888065422949144
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.02      0.03      3234
#          1.0       0.59      0.99      0.74      4592
#
#     accuracy                           0.59      7826
#    macro avg       0.59      0.50      0.38      7826
# weighted avg       0.59      0.59      0.45      7826

# %% [markdown]
# ### Features Fund & Eng

# %%
data = hf.prune(df, fund_eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund_eng, TARGET)
# Out:
# Test AUC: 0.5147096701169483
# Test accuracy: 0.490926199758032
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.67      0.52      3111
#          1.0       0.60      0.37      0.46      4328
#
#     accuracy                           0.49      7439
#    macro avg       0.52      0.52      0.49      7439
# weighted avg       0.53      0.49      0.48      7439

# %% [markdown]
# ## Horizon 60 days

# %%
TARGET = "y_60"

# %% [markdown]
# ### Features Raw

# %%
data = hf.prune(df, eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, eng, TARGET)
# Out:
# Test AUC: 0.5155989360767208
# Test accuracy: 0.41158499327874865
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.82      0.46      2534
#          1.0       0.74      0.23      0.35      5649
#
#     accuracy                           0.41      8183
#    macro avg       0.53      0.52      0.41      8183
# weighted avg       0.61      0.41      0.38      8183

# %% [markdown]
# ### Features Eng

# %%
data = hf.prune(df, eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, eng, TARGET)
# Out:
# Test AUC: 0.5155989360767208
# Test accuracy: 0.41158499327874865
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.82      0.46      2534
#          1.0       0.74      0.23      0.35      5649
#
#     accuracy                           0.41      8183
#    macro avg       0.53      0.52      0.41      8183
# weighted avg       0.61      0.41      0.38      8183

# %% [markdown]
# ### Features Fund

# %%
data = hf.prune(df, fund, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund, TARGET)
# Out:
# Test AUC: 0.47889826190038687
# Test accuracy: 0.6671511627906976
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00      2519
#          1.0       0.67      1.00      0.80      5049
#
#     accuracy                           0.67      7568
#    macro avg       0.33      0.50      0.40      7568
# weighted avg       0.45      0.67      0.53      7568
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ### Features Fund & Eng

# %%
data = hf.prune(df, fund_eng, TARGET)

train, val, test = hf.time_split(data)

Models.run_logistic_regression(train, val, test, fund_eng, TARGET)
# Out:
# Test AUC: 0.5006284541505793
# Test accuracy: 0.4386575685837627
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.78      0.48      2412
#          1.0       0.70      0.27      0.39      4769
#
#     accuracy                           0.44      7181
#    macro avg       0.53      0.52      0.43      7181
# weighted avg       0.58      0.44      0.42      7181

# %% [markdown]
# # Results

# %%
features_map = {
    "raw": raw,
    "eng": eng,
    "fund": fund,
    "fund_eng": fund_eng
}

# %%
features_sets = ['raw', 'eng', 'fund', 'fund_eng']
targets = ['y_1', 'y_20', 'y_60']
res = []

for f, t in product(features_sets, targets):
    print(f, t, type(f), type(t))
    features = features_map[f]
    data = hf.prune(df, features, t)

    train, val, test = hf.time_split(data)
    print(f, t)
    val_acc, test_acc = Models.run_logistic_regression(train, val, test, features, t)

    res.append({
        "Horizon": t,
        "Features": f,
        "Val Accuracy": val_acc,
        "Test Accuracy": test_acc,
    })

res
# Out:
# raw y_1 <class 'str'> <class 'str'>
# raw y_1
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# raw y_20 <class 'str'> <class 'str'>
# raw y_20
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# raw y_60 <class 'str'> <class 'str'>
# raw y_60
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# eng y_1 <class 'str'> <class 'str'>
# eng y_1
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# eng y_20 <class 'str'> <class 'str'>
# eng y_20
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# eng y_60 <class 'str'> <class 'str'>
# eng y_60
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund y_1 <class 'str'> <class 'str'>
# fund y_1
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund y_20 <class 'str'> <class 'str'>
# fund y_20
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund y_60 <class 'str'> <class 'str'>
# fund y_60
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund_eng y_1 <class 'str'> <class 'str'>
# fund_eng y_1
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund_eng y_20 <class 'str'> <class 'str'>
# fund_eng y_20
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# fund_eng y_60 <class 'str'> <class 'str'>
# fund_eng y_60
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/uri/Desktop/BU/ML-Stock-Predictor/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1232: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [{'Horizon': 'y_1',
#   'Features': 'raw',
#   'Val Accuracy': 0.4923070078208573,
#   'Test Accuracy': 0.4985415036119433},
#  {'Horizon': 'y_20',
#   'Features': 'raw',
#   'Val Accuracy': 0.4979015938672902,
#   'Test Accuracy': 0.5279288362438861},
#  {'Horizon': 'y_60',
#   'Features': 'raw',
#   'Val Accuracy': 0.5024241822488832,
#   'Test Accuracy': 0.5045861626797885},
#  {'Horizon': 'y_1',
#   'Features': 'eng',
#   'Val Accuracy': 0.49965201317710106,
#   'Test Accuracy': 0.5042357262457207},
#  {'Horizon': 'y_20',
#   'Features': 'eng',
#   'Val Accuracy': 0.4910048156287877,
#   'Test Accuracy': 0.5230469538782763},
#  {'Horizon': 'y_60',
#   'Features': 'eng',
#   'Val Accuracy': 0.4983610356720456,
#   'Test Accuracy': 0.5155989360767208},
#  {'Horizon': 'y_1',
#   'Features': 'fund',
#   'Val Accuracy': 0.5093368795320723,
#   'Test Accuracy': 0.5039061800930102},
#  {'Horizon': 'y_20',
#   'Features': 'fund',
#   'Val Accuracy': 0.5285954153269234,
#   'Test Accuracy': 0.4742475486393481},
#  {'Horizon': 'y_60',
#   'Features': 'fund',
#   'Val Accuracy': 0.46037978450658146,
#   'Test Accuracy': 0.47889826190038687},
#  {'Horizon': 'y_1',
#   'Features': 'fund_eng',
#   'Val Accuracy': 0.5067229253207568,
#   'Test Accuracy': 0.5028364861844177},
#  {'Horizon': 'y_20',
#   'Features': 'fund_eng',
#   'Val Accuracy': 0.5025293255131965,
#   'Test Accuracy': 0.5147096701169483},
#  {'Horizon': 'y_60',
#   'Features': 'fund_eng',
#   'Val Accuracy': 0.48361722766838544,
#   'Test Accuracy': 0.5006284541505793}]

# %%
res_df = pd.DataFrame(res)
val_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Val Accuracy")
val_df
# Out:
# Horizon        y_1      y_20      y_60
# Features
# eng       0.499652  0.491005  0.498361
# fund      0.509337  0.528595  0.460380
# fund_eng  0.506723  0.502529  0.483617
# raw       0.492307  0.497902  0.502424

# %%
test_df = res_df.pivot(index = "Features", columns = "Horizon", values = "Test Accuracy")
test_df
# Out:
# Horizon        y_1      y_20      y_60
# Features
# eng       0.504236  0.523047  0.515599
# fund      0.503906  0.474248  0.478898
# fund_eng  0.502836  0.514710  0.500628
# raw       0.498542  0.527929  0.504586
